# %%
import pandas as pd
import boto3
import json
import psycopg2
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# # Load DWH Params from a file

# %%
import configparser
import os

config = configparser.ConfigParser()
config.read_file(open('dwh.cfg'))

KEY = os.getenv("AWS_ACCESS_KEY_ID")
SECRET = os.getenv("AWS_SECRET_ACCESS_KEY")

DWH_CLUSTER_TYPE       = config.get("DWH_SETUP","DWH_CLUSTER_TYPE")
DWH_NUM_NODES          = config.get("DWH_SETUP","DWH_NUM_NODES")
DWH_NODE_TYPE          = config.get("DWH_SETUP","DWH_NODE_TYPE")

DWH_CLUSTER_IDENTIFIER = config.get("DWH_SETUP","DWH_CLUSTER_IDENTIFIER")
DWH_DB                 = config.get("CLUSTER","DB_NAME")
DWH_DB_USER            = config.get("CLUSTER","DB_USER")
DWH_DB_PASSWORD        = config.get("CLUSTER","DB_PASSWORD")
DWH_PORT               = config.get("CLUSTER","DB_PORT")

DWH_IAM_ROLE_NAME      = config.get("IAM_ROLE", "DWH_IAM_ROLE_NAME")

(DWH_DB_USER, DWH_DB_PASSWORD, DWH_DB)

pd.DataFrame({"Param":
                  ["DWH_CLUSTER_TYPE", "DWH_NUM_NODES", "DWH_NODE_TYPE", "DWH_CLUSTER_IDENTIFIER", "DWH_DB", "DWH_DB_USER", "DWH_DB_PASSWORD", "DWH_PORT", "DWH_IAM_ROLE_NAME"],
              "Value":
                  [DWH_CLUSTER_TYPE, DWH_NUM_NODES, DWH_NODE_TYPE, DWH_CLUSTER_IDENTIFIER, DWH_DB, DWH_DB_USER, DWH_DB_PASSWORD, DWH_PORT, DWH_IAM_ROLE_NAME]
             })
# Out:
#                     Param       Value
# 0        DWH_CLUSTER_TYPE  multi-node
# 1           DWH_NUM_NODES           4
# 2           DWH_NODE_TYPE   dc2.large
# 3  DWH_CLUSTER_IDENTIFIER  dwhCluster
# 4                  DWH_DB    sparkify
# 5             DWH_DB_USER     dwhuser
# 6         DWH_DB_PASSWORD    Passw0rd
# 7                DWH_PORT        5439
# 8       DWH_IAM_ROLE_NAME     dwhRole

# %% [markdown]
# # Create IAM, Redshift, EC2, & S# clients

# %%
iam = boto3.client('iam',aws_access_key_id=KEY,
                     aws_secret_access_key=SECRET,
                     region_name='us-west-2'
                  )

redshift = boto3.client('redshift',
                       region_name="us-west-2",
                       aws_access_key_id=KEY,
                       aws_secret_access_key=SECRET
                       )

ec2 = boto3.resource('ec2',
                       region_name="us-west-2",
                       aws_access_key_id=KEY,
                       aws_secret_access_key=SECRET
                    )

# Actually, I don't think I need this one                       
s3 = boto3.resource('s3',
                       region_name="us-west-2",
                       aws_access_key_id=KEY,
                       aws_secret_access_key=SECRET
                     )

# %% [markdown]
# # Create IAM Role

# %%
from botocore.exceptions import ClientError

#1.1 Create the role, 
try:
    print("1.1 Creating a new IAM Role") 
    dwhRole = iam.create_role(
        Path='/',
        RoleName=DWH_IAM_ROLE_NAME,
        Description = "Allows Redshift clusters to call AWS services on your behalf.",
        AssumeRolePolicyDocument=json.dumps(
            {'Statement': [{'Action': 'sts:AssumeRole',
               'Effect': 'Allow',
               'Principal': {'Service': 'redshift.amazonaws.com'}}],
             'Version': '2012-10-17'})
    )    
except Exception as e:
    print(e)
    
    
print("1.2 Attaching Policy")

iam.attach_role_policy(RoleName=DWH_IAM_ROLE_NAME,
                       PolicyArn="arn:aws:iam::aws:policy/AmazonS3ReadOnlyAccess"
                      )['ResponseMetadata']['HTTPStatusCode']

print("1.3 Get the IAM role ARN")
roleArn = iam.get_role(RoleName=DWH_IAM_ROLE_NAME)['Role']['Arn']

print(roleArn)
# Out:
# 1.1 Creating a new IAM Role
# An error occurred (EntityAlreadyExists) when calling the CreateRole operation: Role with name dwhRole already exists.
# 1.2 Attaching Policy
# 1.3 Get the IAM role ARN
# arn:aws:iam::229998455760:role/dwhRole

# %% [markdown]
# # Create the Redshift Cluster

# %%
try:
    response = redshift.create_cluster(        
        #HW
        ClusterType=DWH_CLUSTER_TYPE,
        NodeType=DWH_NODE_TYPE,
        NumberOfNodes=int(DWH_NUM_NODES),

        #Identifiers & Credentials
        DBName=DWH_DB,
        ClusterIdentifier=DWH_CLUSTER_IDENTIFIER,
        MasterUsername=DWH_DB_USER,
        MasterUserPassword=DWH_DB_PASSWORD,
        
        #Roles (for s3 access)
        IamRoles=[roleArn]  
    )
except Exception as e:
    print(e)
# Out:
# An error occurred (ClusterAlreadyExists) when calling the CreateCluster operation: Cluster already exists

# %% [markdown]
# # Validate the Redshift cluster is available

# %%
def prettyRedshiftProps(props):
    pd.set_option('display.max_colwidth', None)
    keysToShow = ["ClusterIdentifier", "NodeType", "ClusterStatus", "MasterUsername", "DBName", "Endpoint", "NumberOfNodes", 'VpcId']
    x = [(k, v) for k,v in props.items() if k in keysToShow]
    return pd.DataFrame(data=x, columns=["Key", "Value"])

myClusterProps = redshift.describe_clusters(ClusterIdentifier=DWH_CLUSTER_IDENTIFIER)['Clusters'][0]
prettyRedshiftProps(myClusterProps)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[88], line 7
#       4     x = [(k, v) for k,v in props.items() if k in keysToShow]
#       5     return pd.DataFrame(data=x, columns=["Key", "Value"])
# ----> 7 myClusterProps = redshift.describe_clusters(ClusterIdentifier=DWH_CLUSTER_IDENTIFIER)['Clusters'][0]
#       8 prettyRedshiftProps(myClusterProps)
#
# File ~/Documents/Code/UdacityCloudDeveloper/envs/lib/python3.12/site-packages/botocore/client.py:565, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     561     raise TypeError(
#     562         f"{py_operation_name}() only accepts keyword arguments."
#     563     )
#     564 # The "self" in this scope is referring to the BaseClient.
# --> 565 return self._make_api_call(operation_name, kwargs)
#
# File ~/Documents/Code/UdacityCloudDeveloper/envs/lib/python3.12/site-packages/botocore/client.py:1021, in BaseClient._make_api_call(self, operation_name, api_params)
#    1017     error_code = error_info.get("QueryErrorCode") or error_info.get(
#    1018         "Code"
#    1019     )
#    1020     error_class = self.exceptions.from_code(error_code)
# -> 1021     raise error_class(parsed_response, operation_name)
#    1022 else:
#    1023     return parsed_response
#
# ClientError: An error occurred (InvalidClientTokenId) when calling the DescribeClusters operation: The security token included in the request is invalid.

# %% [markdown]
# # Cluster Endpoint & Role ARN

# %%
DWH_ENDPOINT = myClusterProps['Endpoint']['Address']
DWH_ROLE_ARN = myClusterProps['IamRoles'][0]['IamRoleArn']
print("DWH_ENDPOINT :: ", DWH_ENDPOINT)
print("DWH_ROLE_ARN :: ", DWH_ROLE_ARN)
# Out:
# DWH_ENDPOINT ::  dwhcluster.cvjkim9fsfbc.us-west-2.redshift.amazonaws.com
# DWH_ROLE_ARN ::  arn:aws:iam::229998455760:role/dwhRole

# %% [markdown]
# # Open an incoming  TCP port to access the cluster ednpoint

# %%
try:
    vpc = ec2.Vpc(id=myClusterProps['VpcId'])
    defaultSg = list(vpc.security_groups.all())[0]
    print(defaultSg)
    defaultSg.authorize_ingress(
        GroupName=defaultSg.group_name,
        CidrIp='0.0.0.0/0',
        IpProtocol='TCP',
        FromPort=int(DWH_PORT),
        ToPort=int(DWH_PORT)
    )
except Exception as e:
    print(e)
# Out:
# ec2.SecurityGroup(id='sg-0de7c4f3ea7e375a6')
# An error occurred (InvalidPermission.Duplicate) when calling the AuthorizeSecurityGroupIngress operation: the specified rule "peer: 0.0.0.0/0, TCP, from port: 5439, to port: 5439, ALLOW" already exists

# %% [markdown]
# # Validate Connection

# %%
# %load_ext sql

# %%
conn = psycopg2.connect("host={} dbname={} user={} password={} port={}".format(*config['CLUSTER'].values()))
conn.autocommit = True
cur = conn.cursor()

# %%
cur.execute("SELECT 10")
# conn.commit()
cur.fetchall()
# Out:
# [(10,)]

# %%
cur.execute("SELECT DISTINCT tablename FROM pg_table_def where schemaname='sparkify'")
# conn.commit()
cur.fetchall()
# Out:
# []

# %%
# conn_string="postgresql://{}:{}@{}:{}/{}".format(DWH_DB_USER, DWH_DB_PASSWORD, DWH_ENDPOINT, DWH_PORT,DWH_DB)
# print(conn_string)
# %sql $conn_string

# %% [markdown]
# # Clean Up Resources

# %%
#### CAREFUL!!
#-- Uncomment & run to delete the created resources
redshift.delete_cluster( ClusterIdentifier=DWH_CLUSTER_IDENTIFIER,  SkipFinalClusterSnapshot=True)
#### CAREFUL!!
# Out:
# {'Cluster': {'ClusterIdentifier': 'dwhcluster',
#   'NodeType': 'dc2.large',
#   'ClusterStatus': 'deleting',
#   'ClusterAvailabilityStatus': 'Modifying',
#   'MasterUsername': 'dwhuser',
#   'DBName': 'sparkify',
#   'Endpoint': {'Address': 'dwhcluster.cvjkim9fsfbc.us-west-2.redshift.amazonaws.com',
#    'Port': 5439},
#   'ClusterCreateTime': datetime.datetime(2024, 6, 17, 23, 17, 26, 975000, tzinfo=tzutc()),
#   'AutomatedSnapshotRetentionPeriod': 1,
#   'ManualSnapshotRetentionPeriod': -1,
#   'ClusterSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-0de7c4f3ea7e375a6',
#     'Status': 'active'}],
#   'ClusterParameterGroups': [{'ParameterGroupName': 'default.redshift-1.0',
#     'ParameterApplyStatus': 'in-sync'}],
#   'ClusterSubnetGroupName': 'default',
#   'VpcId': 'vpc-056d8a9859858477e',
#   'AvailabilityZone': 'us-west-2d',
#   'PreferredMaintenanceWindow': 'wed:09:30-wed:10:00',
#   'PendingModifiedValues': {},
#   'ClusterVersion': '1.0',
#   'AllowVersionUpgrade': True,
#   'NumberOfNodes': 4,
#   'PubliclyAccessible': True,
#   'Encrypted': False,
#   'Tags': [],
#   'EnhancedVpcRouting': False,
#   'IamRoles': [{'IamRoleArn': 'arn:aws:iam::229998455760:role/dwhRole',
#     'ApplyStatus': 'in-sync'}],
#   'MaintenanceTrackName': 'current',
#   'DeferredMaintenanceWindows': [],
#   'NextMaintenanceWindowStartTime': datetime.datetime(2024, 6, 19, 9, 30, tzinfo=tzutc()),
#   'ClusterNamespaceArn': 'arn:aws:redshift:us-west-2:229998455760:namespace:7243afd5-0699-49c8-a1f2-73458ce65f42',
#   'TotalStorageCapacityInMegaBytes': 1600000,
#   'AquaConfiguration': {'AquaStatus': 'disabled',
#    'AquaConfigurationStatus': 'auto'},
#   'MultiAZ': 'Disabled'},
#  'ResponseMetadata': {'RequestId': '5aad725e-3882-4c5e-b6c2-5ed553a988ed',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '5aad725e-3882-4c5e-b6c2-5ed553a988ed',
#    'content-type': 'text/xml',
#    'content-length': '2887',
#    'date': 'Wed, 19 Jun 2024 02:47:52 GMT'},
#   'RetryAttempts': 0}}

# %%
myClusterProps = redshift.describe_clusters(ClusterIdentifier=DWH_CLUSTER_IDENTIFIER)['Clusters'][0]
prettyRedshiftProps(myClusterProps)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 myClusterProps = redshift.describe_clusters(ClusterIdentifier=DWH_CLUSTER_IDENTIFIER)['Clusters'][0]
#       2 prettyRedshiftProps(myClusterProps)
#
# File ~/Documents/Code/UdacityCloudDeveloper/envs/lib/python3.12/site-packages/botocore/client.py:565, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     561     raise TypeError(
#     562         f"{py_operation_name}() only accepts keyword arguments."
#     563     )
#     564 # The "self" in this scope is referring to the BaseClient.
# --> 565 return self._make_api_call(operation_name, kwargs)
#
# File ~/Documents/Code/UdacityCloudDeveloper/envs/lib/python3.12/site-packages/botocore/client.py:1021, in BaseClient._make_api_call(self, operation_name, api_params)
#    1017     error_code = error_info.get("QueryErrorCode") or error_info.get(
#    1018         "Code"
#    1019     )
#    1020     error_class = self.exceptions.from_code(error_code)
# -> 1021     raise error_class(parsed_response, operation_name)
#    1022 else:
#    1023     return parsed_response
#
# ClientError: An error occurred (InvalidClientTokenId) when calling the DescribeClusters operation: The security token included in the request is invalid.

# %%
#### CAREFUL!!
#-- Uncomment & run to delete the created resources
iam.detach_role_policy(RoleName=DWH_IAM_ROLE_NAME, PolicyArn="arn:aws:iam::aws:policy/AmazonS3ReadOnlyAccess")
iam.delete_role(RoleName=DWH_IAM_ROLE_NAME)
#### CAREFUL!!
# Out:
# {'ResponseMetadata': {'RequestId': 'e72aa4da-4ebc-4271-81bf-bd5baab71dd5',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Mon, 17 Jun 2024 22:02:48 GMT',
#    'x-amzn-requestid': 'e72aa4da-4ebc-4271-81bf-bd5baab71dd5',
#    'content-type': 'text/xml',
#    'content-length': '200'},
#   'RetryAttempts': 0}}

# %% [markdown]
# # Fiddle

# %%
cur.execute("""
CREATE TABLE songs (
    num_songs INTEGER,
    artist_id VARCHAR(50),
    artist_latitude DECIMAL(9,6),
    artist_longitude DECIMAL(9,6),
    artist_location VARCHAR(255),
    artist_name VARCHAR(255),
    song_id VARCHAR(50),
    title VARCHAR(255),
    duration DECIMAL(15,5),
    year INTEGER
);
""")
cur.fetchall()
# Out:
# ---------------------------------------------------------------------------
# DuplicateTable                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 cur.execute("""
#       2 CREATE TABLE songs (
#       3     num_songs INTEGER,
#       4     artist_id VARCHAR(50),
#       5     artist_latitude DECIMAL(9,6),
#       6     artist_longitude DECIMAL(9,6),
#       7     artist_location VARCHAR(255),
#       8     artist_name VARCHAR(255),
#       9     song_id VARCHAR(50),
#      10     title VARCHAR(255),
#      11     duration DECIMAL(15,5),
#      12     year INTEGER
#      13 );
#      14 """)
#      15 cur.fetchall()
#
# DuplicateTable: Relation "songs" already exists

# %%
cur.execute("""
select * from songs limit 100
""")
cur.fetchall()
# Out:
# [(1,
#   'AR9E1QW1187B999A34',
#   None,
#   None,
#   '',
#   'Mikel Erentxun',
#   'SOSBVKG12A8C1409B8',
#   'En Que Mujer',
#   Decimal('210.33751'),
#   2000),
#  (1,
#   'AR3793X1187FB50CB3',
#   None,
#   None,
#   'Middlesbrough, England',
#   'Chris Rea',
#   'SODHVES12A6701CE6B',
#   'Driving Home For Christmas',
#   Decimal('241.16200'),
#   1986),
#  (1,
#   'ARNULK21187FB46537',
#   None,
#   None,
#   '',
#   'Grandmaster Flash',
#   'SOOTBYV12AB0186EC8',
#   'Gold',
#   Decimal('260.91057'),
#   1988),
#  (1,
#   'AROLE161187B98F7E4',
#   None,
#   None,
#   '',
#   'Olle Adolphson',
#   'SOOBRRO12A8C139153',
#   "Tatuerarevalsen (remaster '03)",
#   Decimal('181.28934'),
#   0),
#  (1,
#   'AR52SSB1187B9B3E5F',
#   None,
#   None,
#   '',
#   'Aquagen',
#   'SOQNYWI12AB01840AA',
#   'Phatt Bass',
#   Decimal('242.70321'),
#   0),
#  (1,
#   'AR567PN1187FB4B4F2',
#   None,
#   None,
#   '',
#   'Moss',
#   'SONNOCP12A8C145220',
#   'Silent Hill',
#   Decimal('329.35138'),
#   2009),
#  (1,
#   'AR98JLC1187B9ADE23',
#   None,
#   None,
#   'Los Angeles, CA',
#   'Megadeth',
#   'SOYSCPE12AB0181BBF',
#   'Blackmail The Universe',
#   Decimal('273.26648'),
#   2004),
#  (1,
#   'ARYN2HS1187FB4CD67',
#   Decimal('35.914630'),
#   Decimal('-79.056610'),
#   'Chapel Hill, NC',
#   'Archers Of Loaf',
#   'SOQBUPE12A8C13B9DC',
#   'Greatest of All Time',
#   Decimal('231.13097'),
#   1997),
#  (1,
#   'ARDQKMM1187FB3F4F0',
#   Decimal('32.778149'),
#   Decimal('-96.795400'),
#   'Dallas, TX',
#   'Roky Erickson',
#   'SOHKZSX12A6D4F81BE',
#   'Before In The Beginning (Album Version)',
#   Decimal('396.95627'),
#   0),
#  (1,
#   'AR2QIVJ1187B9AF497',
#   None,
#   None,
#   'Atlanta, GA',
#   'YoungBloodZ Featuring Cutty',
#   'SOQNKDT12A8C1412CA',
#   'Spending Some Change Featuring Cutty',
#   Decimal('243.43465'),
#   2005),
#  (1,
#   'ARPYBWQ1187B989C0D',
#   None,
#   None,
#   '',
#   'Natural Elements',
#   'SOPOIQJ12A6701C8CF',
#   'Mayday',
#   Decimal('338.10239'),
#   1998),
#  (1,
#   'ARPZQT71187FB3C88A',
#   Decimal('57.049349'),
#   Decimal('9.916290'),
#   'Aalborg, Denmark',
#   'Figurines',
#   'SOTCWQC12A8C1388D9',
#   'Race You',
#   Decimal('182.28200'),
#   2005),
#  (1,
#   'ARUWB5W1187B98D7A1',
#   None,
#   None,
#   'Helsinki, Finland',
#   'Ensiferum',
#   'SOCOQUZ12AB0181A1E',
#   "Warrior's Quest",
#   Decimal('291.02974'),
#   1999),
#  (1,
#   'ARNI7VZ1187B9AA6AF',
#   None,
#   None,
#   'Alexandria, VA',
#   'Joaquin Phoenix',
#   'SOEJRUR12AB018B67F',
#   "You're My Baby",
#   Decimal('132.25751'),
#   2005),
#  (1,
#   'ARHPGAD1187B9AE791',
#   Decimal('51.506320'),
#   Decimal('-0.127140'),
#   'London, England',
#   'Fluke',
#   'SOLGMGB12A58A7E4E6',
#   'Electric Guitar (Headstock)',
#   Decimal('334.91546'),
#   1993),
#  (1,
#   'ARFU3UI1187B9A7372',
#   Decimal('50.828209'),
#   Decimal('-0.134490'),
#   'Brighton / Los Angeles United Kingdom',
#   'Che Sudaka',
#   'SOYWXKY12A6D4FB1A4',
#   'Somos Más - Qué Difícil',
#   Decimal('150.25586'),
#   2005),
#  (1,
#   'AR6GJDZ1187B991E46',
#   Decimal('19.431899'),
#   Decimal('-99.132850'),
#   'Mexico City, Mexico',
#   'KALIMBA',
#   'SOZBOLJ12AB018B0EC',
#   'Volcán',
#   Decimal('352.67872'),
#   2009),
#  (1,
#   'AR6AKW41187FB5B046',
#   None,
#   None,
#   '',
#   'Sonic Division',
#   'SOOULII12AB0182A1B',
#   'Day And Night',
#   Decimal('511.42484'),
#   0),
#  (1,
#   'ARZDZR21187B99C78C',
#   Decimal('53.409770'),
#   Decimal('-2.978479'),
#   'Liverpool, England',
#   'The Swinging Blue Jeans',
#   'SOLHYNZ12A8151C77E',
#   'Dizzy Chimes',
#   Decimal('146.59872'),
#   0),
#  (1,
#   'ARTM8L21187B99F8F9',
#   Decimal('53.479599'),
#   Decimal('-2.248810'),
#   'Manchester, England',
#   'Any Trouble',
#   'SOTKQRZ12A8C13BDBD',
#   'Playing Bogart',
#   Decimal('164.36199'),
#   2002),
#  (1,
#   'AR5WAUE1187FB40839',
#   Decimal('38.976700'),
#   Decimal('-76.489930'),
#   'Annapolis, MD',
#   "Jimmie's Chicken Shack",
#   'SOZAATB12A8C1385A7',
#   'Nose Face',
#   Decimal('201.06404'),
#   0),
#  (1,
#   'AR7MCVK1187FB53CB1',
#   Decimal('37.487600'),
#   Decimal('139.838290'),
#   'JP',
#   'Kagerou',
#   'SOYKRYP12A8C13BE7D',
#   'Baita no Yuuutsu',
#   Decimal('165.40689'),
#   2006),
#  (1,
#   'ARVL39W1187B989514',
#   None,
#   None,
#   '',
#   "Michel'le",
#   'SORJWUT12A8C1342AC',
#   'Never Been In Love (LP Version)',
#   Decimal('227.44771'),
#   1989),
#  (1,
#   'ARGXNS21187B999665',
#   Decimal('27.975800'),
#   Decimal('-81.541060'),
#   'Florida',
#   'Tina Britt',
#   'SOBHGWG12A6D4F50D2',
#   'He Put The Hurt On Me',
#   Decimal('177.94567'),
#   2006),
#  (1,
#   'ARPMAZJ1187FB3C65F',
#   None,
#   None,
#   'Connecticut',
#   'Keel',
#   'SOLPJPD12AB018D636',
#   'Gimme That',
#   Decimal('211.43465'),
#   2010),
#  (1,
#   'AR98ZSW1187B98E82C',
#   None,
#   None,
#   '',
#   'Kalle Baah',
#   'SOKXFPD12AB018BA1F',
#   'Beggarman Story',
#   Decimal('275.43464'),
#   1992),
#  (1,
#   'ARMF8CE1187B98CD05',
#   None,
#   None,
#   'TUCSON, Arizona',
#   'Maze Featuring Frankie Beverly',
#   'SOFTZNG12A6D4F69D3',
#   'Southern Girl (Live) (Feat. Frankie Beverly)',
#   Decimal('394.42239'),
#   0),
#  (1,
#   'AR5U3PY1187B9A50DA',
#   None,
#   None,
#   '',
#   'Birdy Nam Nam',
#   'SOZQYNK12A8C13EA4E',
#   'Pass It On',
#   Decimal('200.41098'),
#   2006),
#  (1,
#   'ARCJBLL1187B9908C3',
#   Decimal('52.406979'),
#   Decimal('-1.507760'),
#   'Coventry, England',
#   'The Specials',
#   'SOQOKWC12A58A768DF',
#   'Too Hot (2002 Digital Remaster)',
#   Decimal('188.78648'),
#   0),
#  (1,
#   'ARF3HEO1187B9AF2F4',
#   None,
#   None,
#   '',
#   'Donnie McClurkin',
#   'SOTJLKO12A8AE4888B',
#   'All I Ever Really Wanted',
#   Decimal('198.58240'),
#   0),
#  (1,
#   'AR3LNA71187B996A41',
#   None,
#   None,
#   '',
#   'Nagisa Ni Te',
#   'SOBCQUJ12A6D4FBD39',
#   'After a Song',
#   Decimal('253.33506'),
#   2004),
#  (1,
#   'ARHBE351187FB3B0CD',
#   None,
#   None,
#   '',
#   'Holly Golightly',
#   'SOAXHOM12AC95F02AE',
#   'Through Sun and Wine',
#   Decimal('198.11220'),
#   2004),
#  (1,
#   'ARWYYZP1187FB4FDB7',
#   None,
#   None,
#   '',
#   'Mylène Farmer',
#   'SOVPMJD12A6D4F8152',
#   'Et Tournoie',
#   Decimal('270.81097'),
#   0),
#  (1,
#   'ARAW35N1187B994CCA',
#   None,
#   None,
#   '',
#   'Queensryche',
#   'SOBKKRK12AF729F24D',
#   'Lady Jane',
#   Decimal('254.58893'),
#   1994),
#  (1,
#   'ARARO7M1187FB5C0B3',
#   Decimal('40.714550'),
#   Decimal('-74.007120'),
#   'NY - New York City',
#   'Chieli Minucci',
#   'SOWTIOB12A8C139D36',
#   'Without You',
#   Decimal('426.21341'),
#   2003),
#  (1,
#   'AROAQZN1187FB3F866',
#   Decimal('29.953690'),
#   Decimal('-90.077709'),
#   'New Orleans, LA',
#   'Master P',
#   'SOYKIUW12A6D4F3A90',
#   'Souljas',
#   Decimal('212.76688'),
#   0),
#  (1,
#   'ARN7OQ21187FB5A6B3',
#   None,
#   None,
#   'Greenwood, MS',
#   'Furry Lewis',
#   'SOQKKCG12AB017D5C4',
#   'Old Hobo',
#   Decimal('234.78811'),
#   2003),
#  (1,
#   'ARBJ3VU1187B9B472D',
#   None,
#   None,
#   '',
#   'Love Of Lesbian',
#   'SOCZPVM12AB0183612',
#   'Segundo asalto',
#   Decimal('215.66649'),
#   2009),
#  (1,
#   'ARSRFOY1187B9917DA',
#   Decimal('41.884149'),
#   Decimal('-87.632409'),
#   'Chicago, IL',
#   'Otis Taylor',
#   'SOVNVPF12A8C13AD4A',
#   'Round and Round',
#   Decimal('107.83302'),
#   2001),
#  (1,
#   'ARHM7SO1187B988C1C',
#   None,
#   None,
#   'Halifaz, Nova Scotia, Canada',
#   'Josh Martinez',
#   'SOVZJCG12A58A79527',
#   'Absinth tears (feat. Mother Mother)',
#   Decimal('209.34485'),
#   2008),
#  (1,
#   'ARR6VQ01187B990E9B',
#   None,
#   None,
#   '',
#   'Kotiteollisuus',
#   'SOCTYYN12AB0182DB9',
#   'Päällekirjoitus',
#   Decimal('155.79383'),
#   1998),
#  (1,
#   'AR7CCS31187B98C531',
#   None,
#   None,
#   '',
#   'Tom Barabas',
#   'SOAKCYS12AB01852C7',
#   'Sedona Suite (Sunrise/Prayer/Joy/Sunset)',
#   Decimal('743.36608'),
#   1992),
#  (1,
#   'ARCM19K1187FB3F447',
#   None,
#   None,
#   '',
#   'When The Empire Falls',
#   'SOMLFXG12A8C133076',
#   'Dark places',
#   Decimal('266.34404'),
#   2008),
#  (1,
#   'AR1LQNB1187B9A6AE5',
#   None,
#   None,
#   '',
#   'La Portuaria',
#   'SOMUULD12A6D4FBB30',
#   'Hasta El Final',
#   Decimal('224.91382'),
#   2005),
#  (1,
#   'AR9PINM1187FB51FDD',
#   Decimal('40.121389'),
#   Decimal('-80.005949'),
#   'Bentleyville, PA',
#   'Ray Anthony',
#   'SOQXDHK12A81C2134A',
#   'Basin Street Blues (Digitally Remastered 04)',
#   Decimal('191.79057'),
#   0),
#  (1,
#   'AR5H5G11187FB3B8A4',
#   None,
#   None,
#   '',
#   'Project Polaroid (tom c3 & kool keith)',
#   'SOGJWWV12A8C13D362',
#   'Space 8000',
#   Decimal('218.90566'),
#   2006),
#  (1,
#   'AR3GCYN1187B9A279F',
#   None,
#   None,
#   'Texas',
#   'Gary P. Nunn',
#   'SOIWHZD12AB0182328',
#   'Folklife',
#   Decimal('367.59465'),
#   0),
#  (1,
#   'ARP32X81187B99EBF5',
#   Decimal('42.331679'),
#   Decimal('-83.047920'),
#   'Detroit, MI',
#   'Vanessa Bell Armstrong',
#   'SOVWHFZ12A8C14489D',
#   'Greater',
#   Decimal('419.68281'),
#   0),
#  (1,
#   'ARPWGMN1187FB560E3',
#   None,
#   None,
#   '',
#   'C-Rayz Walz',
#   'SOROOWB12A8C13F386',
#   'Mark Of The Beast',
#   Decimal('103.81016'),
#   2005),
#  (1,
#   'ARZQYSZ1187FB3AC39',
#   None,
#   None,
#   'Staten Island, NY',
#   'Ghostface',
#   'SOCOGPZ12A6701D924',
#   'The Letter',
#   Decimal('81.08362'),
#   2004),
#  (1,
#   'ARV16Y31187B9B14E7',
#   Decimal('28.811100'),
#   Decimal('-81.877279'),
#   'Leesburg, FL',
#   'Johnny Thunders',
#   'SOFIZAQ12AC468DB69',
#   'In Cold Blood',
#   Decimal('146.80770'),
#   1996),
#  (1,
#   'ARQUB8N1187B9A07DE',
#   None,
#   None,
#   'Italy',
#   'Ufomammut',
#   'SONVRAV12AF72A0380',
#   'Lacrimosa',
#   Decimal('412.83873'),
#   2004),
#  (1,
#   'ARDIKTW1187FB4C052',
#   Decimal('31.168900'),
#   Decimal('-100.077150'),
#   'Texas',
#   'Helstar',
#   'SONDRVA12AB0189257',
#   'The King Of Hell',
#   Decimal('388.33587'),
#   2008),
#  (1,
#   'ARAFDF11187FB3AFD7',
#   None,
#   None,
#   '',
#   'Evol Intent',
#   'SOSQAQP12A58A78C2A',
#   'Timeline',
#   Decimal('458.99709'),
#   0),
#  (1,
#   'ARR3ZVN1187FB55682',
#   None,
#   None,
#   'Providence RI',
#   'Deer Tick',
#   'SOTRPJN12AB0182298',
#   'Christ Jesus',
#   Decimal('319.65994'),
#   2007),
#  (1,
#   'AR75KUV1187FB5722B',
#   None,
#   None,
#   '',
#   'Os Replicantes',
#   'SOWJFGW12AB01861C4',
#   'Nicotina',
#   Decimal('79.51627'),
#   1987),
#  (1,
#   'ARTS26V1187FB3F9FE',
#   None,
#   None,
#   '',
#   '883',
#   'SOCIBEJ12A67020453',
#   'Come deve andare',
#   Decimal('274.41586'),
#   2001),
#  (1,
#   'ARWCIEL1187FB42EF5',
#   Decimal('39.290550'),
#   Decimal('-76.609600'),
#   'B-More',
#   'Beach House',
#   'SOGMORP12A8C13EF63',
#   'Auburn and Ivory',
#   Decimal('270.00117'),
#   2006),
#  (1,
#   'ARHAJH611C8A4219F1',
#   None,
#   None,
#   '',
#   "La Bottega Dell'Arte",
#   'SODJYTL12A8C14550E',
#   'Noi Nel Bene_ Noi Nel Male',
#   Decimal('223.24199'),
#   0),
#  (1,
#   'AR6Y22S1187B99906F',
#   None,
#   None,
#   '',
#   'Smartbomb',
#   'SONSPZE12AB01819CE',
#   'Complicate It',
#   Decimal('233.27302'),
#   2001),
#  (1,
#   'AROVXZM1187FB3C3DB',
#   None,
#   None,
#   '',
#   'Richard Durand',
#   'SOIQFYZ12AB017D108',
#   'Weep (Sundown Mix)',
#   Decimal('510.01423'),
#   0),
#  (1,
#   'ARVYYRY1187B9953F0',
#   Decimal('-26.204940'),
#   Decimal('28.040030'),
#   'Johannesburg, South Africa',
#   'Trevor Rabin',
#   'SOJDUQC12AB0181FE6',
#   'Siphon Searches',
#   Decimal('242.96444'),
#   2009),
#  (1,
#   'AR4ZHF11187FB4D8DF',
#   None,
#   None,
#   '',
#   'Ubar Tmar',
#   'SOIIZSD12AB0184A86',
#   'Eternal Return',
#   Decimal('438.25587'),
#   1997),
#  (1,
#   'ARE50SC1187B98C04A',
#   Decimal('60.171160'),
#   Decimal('24.932580'),
#   'Helsinki, Finland',
#   'The 69 Eyes',
#   'SOYQKGK12A8C133B5E',
#   'Wild Talk',
#   Decimal('244.45341'),
#   1995),
#  (1,
#   'AR88PUH1187FB52B3B',
#   None,
#   None,
#   'Rahway, NJ',
#   'Eric Roberson',
#   'SOSOJTG12A8C143272',
#   'Just A Dream',
#   Decimal('254.27546'),
#   2005),
#  (1,
#   'ARDQO721187FB3C6D9',
#   None,
#   None,
#   '',
#   'Rodney O & Joe Cooley',
#   'SOIKVVS12AB0184063',
#   'Nutty Block',
#   Decimal('172.01587'),
#   1991),
#  (1,
#   'ARUB0K61187B9B9AC3',
#   Decimal('29.651949'),
#   Decimal('-82.323179'),
#   'Gainesville, FL',
#   'Hot Water Music',
#   'SOVXCID12A8C137FC0',
#   'There Are Already Roses',
#   Decimal('194.92526'),
#   2004),
#  (1,
#   'ARCIDJA1187FB589B7',
#   None,
#   None,
#   'Vancouver BC',
#   'Matthew Good',
#   'SORNBHC12A6D4FD262',
#   'Avalanche',
#   Decimal('446.87628'),
#   2003),
#  (1,
#   'ARW0VNE1187B9AEF71',
#   Decimal('56.954680'),
#   Decimal('-98.308970'),
#   'Canada',
#   'Gorguts',
#   'SOLUIFJ12A8AE46CEF',
#   '... And Then Comes Lividity (Album Version)',
#   Decimal('43.88526'),
#   1991),
#  (1,
#   'AR0ON211187FB5B6D2',
#   None,
#   None,
#   '',
#   'George Howard',
#   'SOMORKL12A6D4F926B',
#   "(You Caught Me) Smilin'",
#   Decimal('302.28852'),
#   0),
#  (1,
#   'AREL88S1187B9B1466',
#   Decimal('62.198450'),
#   Decimal('17.551420'),
#   'Sweden',
#   'Europe',
#   'SOQUAMB12AB0181F51',
#   'Hero',
#   Decimal('266.65751'),
#   2004),
#  (1,
#   'ARA49BA1187FB5542E',
#   None,
#   None,
#   '',
#   'CRW',
#   'SOBGCRD12A8C1356BC',
#   'I Feel Love - R.A.F. Zone Mix',
#   Decimal('321.17505'),
#   0),
#  (1,
#   'ARSKAM81187FB44F46',
#   Decimal('32.778149'),
#   Decimal('-96.795400'),
#   'Dallas, TX',
#   'Jackopierce',
#   'SOQKHIQ12A58A7B30B',
#   'Witch In The Old Man',
#   Decimal('146.15465'),
#   1994),
#  (1,
#   'ARE65ST1187FB4F994',
#   None,
#   None,
#   'TORONTO',
#   'MSTRKRFT / JFK / AL P / Jahmal Tonge',
#   'SOHILRE129F06B7511',
#   'Breakaway',
#   Decimal('217.70403'),
#   2009),
#  (1,
#   'ARK6MFB1187B9A4C11',
#   None,
#   None,
#   '',
#   'Thomas Newman',
#   'SOQIXCA12AB017DAC2',
#   'The Bright Young Man',
#   Decimal('211.12118'),
#   2009),
#  (1,
#   'AR1DR0E1187FB48F61',
#   None,
#   None,
#   'Cross Lane, WV',
#   'Kathy Mattea',
#   'SOTTJUN12A8C132C22',
#   'Sally In the Garden',
#   Decimal('44.64280'),
#   2008),
#  (1,
#   'AR35ZU21187B9B65FC',
#   Decimal('57.153820'),
#   Decimal('-2.106790'),
#   'Aberdeen, Scotland',
#   'Geneva',
#   'SOXLFQD12A8C141927',
#   'Tranquillizer',
#   Decimal('211.59137'),
#   1997),
#  (1,
#   'AR4117R1187B9ACDF7',
#   None,
#   None,
#   'Burbank, CA',
#   'Lovehatehero',
#   'SORYYAW12AC468BF85',
#   'Come And Get It',
#   Decimal('193.09669'),
#   2009),
#  (1,
#   'AR1G6WM1187FB5C014',
#   None,
#   None,
#   '',
#   'Gary Lewis & The Playboys',
#   'SOKFMQE12A6D4F41B7',
#   'Tina (I Held You In My Arms) (1989 Digital Remaster)',
#   Decimal('125.46567'),
#   0),
#  (1,
#   'ARISGWX119B8669508',
#   None,
#   None,
#   '',
#   'Ooah',
#   'SOMJJJT12AB0182379',
#   'Foolish Silence',
#   Decimal('276.89751'),
#   0),
#  (1,
#   'ARCQGTE1187B98F814',
#   None,
#   None,
#   '',
#   'Nichole Nordeman',
#   'SOQIZDW12A6D4F9BB1',
#   'Do You Hear What I Hear',
#   Decimal('236.51220'),
#   2005),
#  (1,
#   'ARWHM281187FB3D381',
#   Decimal('37.805059'),
#   Decimal('-122.273020'),
#   'Oakland, CA',
#   'Souls Of Mischief',
#   'SONCPQC12A58A7D3A7',
#   'Spark',
#   Decimal('220.96933'),
#   2002),
#  (1,
#   'AR1OBRC1187FB59AD4',
#   None,
#   None,
#   'POLAND',
#   'Behemoth',
#   'SOBXGKH12AB017DDB6',
#   'Before The Æons Came',
#   Decimal('178.33751'),
#   2004),
#  (1,
#   'ARTHQJR1187FB43D90',
#   None,
#   None,
#   '',
#   'Dan Winter',
#   'SOSVXQU12AB0184DB0',
#   "Don't Stop Push It Now",
#   Decimal('187.53261'),
#   0),
#  (1,
#   'ART568W1187B98C73E',
#   Decimal('39.145269'),
#   Decimal('-75.418760'),
#   'San Diego, CA',
#   'Stephen Bishop',
#   'SOSLADS12AB0184E97',
#   'Only The Heart Within You',
#   Decimal('251.71546'),
#   1994),
#  (1,
#   'AR9DE5T1187FB48CA3',
#   None,
#   None,
#   '',
#   'Gulabi Sapera_Titi Robin',
#   'SOAAHZO12A67AE1265',
#   'Agni Sha Kshi',
#   Decimal('229.69424'),
#   0),
#  (1,
#   'AR02YGA1187B9B8AC4',
#   Decimal('-34.608519'),
#   Decimal('-58.373539'),
#   'Buenos Aires',
#   'Bersuit Vergarabat',
#   'SOMXGMJ12AB0183EC5',
#   'Bolero Militar',
#   Decimal('208.56118'),
#   1996),
#  (1,
#   'ARI3W2K1187FB37DC5',
#   Decimal('-12.970020'),
#   Decimal('-38.504559'),
#   'Salvador, Bahia',
#   'Ivete Sangalo',
#   'SOYHJMF12AB017F7DA',
#   'Retratos E Canções',
#   Decimal('225.33179'),
#   2003),
#  (1,
#   'ARLFAHS11E2835E9FE',
#   None,
#   None,
#   '',
#   'Angela Ro Ro',
#   'SOKYDWX12A6D4FA455',
#   "Don't Let Me Be Misunderstood",
#   Decimal('335.85586'),
#   2006),
#  (1,
#   'ARBYB6F1187FB3F23D',
#   Decimal('42.503819'),
#   Decimal('12.573470'),
#   'ITALY',
#   'Venus',
#   'SOOPCJF12A6D4F911E',
#   'Wanda Wultz',
#   Decimal('229.38077'),
#   0),
#  (1,
#   'ARXFEEL1187FB4B6CE',
#   None,
#   None,
#   '',
#   'Born From Pain',
#   'SOGLYUC12AB0187E67',
#   'IMMORTALITY',
#   Decimal('237.73994'),
#   1999),
#  (1,
#   'AREHK7O1187B9ADDD7',
#   None,
#   None,
#   'J�ping, Sweden',
#   'The Cardigans',
#   'SOCNCGL127D9786D66',
#   'Lovefool',
#   Decimal('198.21669'),
#   1996),
#  (1,
#   'AR1RDHG1187B990383',
#   None,
#   None,
#   '',
#   'Sandy B',
#   'SOQKOPI12A6D4F98A3',
#   'Make The World Go Round',
#   Decimal('230.29506'),
#   1996),
#  (1,
#   'ARCIDJA1187FB589B7',
#   None,
#   None,
#   'Vancouver BC',
#   'Matthew Good',
#   'SOKNDAI12A6D4FE2B4',
#   'House of Smoke and Mirrors',
#   Decimal('363.20607'),
#   2003),
#  (1,
#   'ARRAKQV1187FB3F861',
#   None,
#   None,
#   '',
#   'Arnaldo Antunes',
#   'SOOYWCM12AB0189519',
#   'Qualquer Coisa',
#   Decimal('181.28934'),
#   2007),
#  (1,
#   'AR3MSAN1187B98F06B',
#   Decimal('33.748309'),
#   Decimal('-84.391109'),
#   'Atlanta, GA',
#   'OutKast',
#   'SOZCATU12A58A7BD8D',
#   "Happy Valentine's Day",
#   Decimal('323.10811'),
#   2003),
#  (1,
#   'ARGUYNJ11C8A41506B',
#   None,
#   None,
#   'Compton, CA',
#   'TYGA',
#   'SOAYKIF12AC468C63E',
#   'Diddy Bop',
#   Decimal('111.49016'),
#   0),
#  (1,
#   'ARML7XL1187FB43F59',
#   None,
#   None,
#   'Newton County',
#   'Boondox',
#   'SODAYSL12AB018FFFA',
#   'Nothing To Lose',
#   Decimal('260.10077'),
#   2010),
#  (1,
#   'ARQGNEN1187FB4494C',
#   None,
#   None,
#   '',
#   'Gabinete Caligari',
#   'SONOXGB12A81C218C8',
#   'Viaje Al Averno',
#   Decimal('169.69098'),
#   1991),
#  (1,
#   'AR163GO1187B98C940',
#   Decimal('45.512279'),
#   Decimal('-73.554389'),
#   'Montreal, Quebec, Canada',
#   'Bran Van 3000',
#   'SOGVFRB12AF72A45D1',
#   'Lucknow',
#   Decimal('128.88771'),
#   1998)]

# %%
cur.execute("""
drop table songs
""")
cur.fetchall()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[38], line 4
#       1 cur.execute("""
#       2 drop table songs
#       3 """)
# ----> 4 cur.fetchall()
#
# ProgrammingError: no results to fetch

# %%
cur.execute("""
select * from song_events
""")
cur.fetchall()
# Out:
# [(None,
#   'Logged Out',
#   None,
#   None,
#   0,
#   None,
#   None,
#   'free',
#   None,
#   'PUT',
#   'Login',
#   None,
#   52,
#   None,
#   307,
#   1541207073796,
#   None,
#   None),
#  (None,
#   'Logged In',
#   'Celeste',
#   'F',
#   1,
#   'Williams',
#   None,
#   'free',
#   'Klamath Falls, OR',
#   'GET',
#   'Home',
#   1541077528796,
#   52,
#   None,
#   200,
#   1541207123796,
#   '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.103 Safari/537.36"',
#   53),
#  ('Mynt',
#   'Logged In',
#   'Celeste',
#   'F',
#   2,
#   'Williams',
#   166.94812,
#   'free',
#   'Klamath Falls, OR',
#   'PUT',
#   'NextSong',
#   1541077528796,
#   52,
#   'Playa Haters',
#   200,
#   1541207150796,
#   '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.103 Safari/537.36"',
#   53),
#  ('Taylor Swift',
#   'Logged In',
#   'Celeste',
#   'F',
#   3,
#   'Williams',
#   230.47791,
#   'free',
#   'Klamath Falls, OR',
#   'PUT',
#   'NextSong',
#   1541077528796,
#   52,
#   'You Belong With Me',
#   200,
#   1541207316796,
#   '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.103 Safari/537.36"',
#   53),
#  ('Amy Winehouse',
#   'Logged In',
#   'Celeste',
#   'F',
#   4,
#   'Williams',
#   229.85098,
#   'free',
#   'Klamath Falls, OR',
#   'PUT',
#   'NextSong',
#   1541077528796,
#   52,
#   'Valerie',
#   200,
#   1541207546796,
#   '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.103 Safari/537.36"',
#   53),
#  ('Jimmy Eat World',
#   'Logged In',
#   'Celeste',
#   'F',
#   5,
#   'Williams',
#   285.83138,
#   'free',
#   'Klamath Falls, OR',
#   'PUT',
#   'NextSong',
#   1541077528796,
#   52,
#   'Dizzy',
#   200,
#   1541207775796,
#   '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.103 Safari/537.36"',
#   53),
#  (None,
#   'Logged Out',
#   None,
#   None,
#   0,
#   None,
#   None,
#   'free',
#   None,
#   'GET',
#   'Home',
#   None,
#   18,
#   None,
#   200,
#   1541239749796,
#   None,
#   None),
#  ('Maldita Nerea',
#   'Logged In',
#   'Anabelle',
#   'F',
#   0,
#   'Simpson',
#   241.162,
#   'free',
#   'Philadelphia-Camden-Wilmington, PA-NJ-DE-MD',
#   'PUT',
#   'NextSong',
#   1541044398796,
#   158,
#   'Supelicula',
#   200,
#   1541254670796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"',
#   69),
#  ('Fluke',
#   'Logged In',
#   'Connar',
#   'M',
#   0,
#   'Moreno',
#   478.92853,
#   'free',
#   'Houston-The Woodlands-Sugar Land, TX',
#   'PUT',
#   'NextSong',
#   1540823606796,
#   168,
#   'Bermuda',
#   200,
#   1541257880796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10) AppleWebKit/538.46 (KHTML, like Gecko) Version/8.0 Safari/538.46"',
#   62),
#  ('Habib KoitÃ\x83Â©',
#   'Logged In',
#   'Jayden',
#   'M',
#   0,
#   'Fox',
#   285.1522,
#   'free',
#   'New Orleans-Metairie, LA',
#   'PUT',
#   'NextSong',
#   1541033612796,
#   185,
#   'Din Din Wo',
#   200,
#   1541259368796,
#   '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"',
#   101),
#  ('The Kooks',
#   'Logged In',
#   'Sara',
#   'F',
#   0,
#   'Johnson',
#   132.25751,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   "Eddie's Gun",
#   200,
#   1541260356796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Blues Traveler',
#   'Logged In',
#   'Sara',
#   'F',
#   1,
#   'Johnson',
#   290.24608,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Hook',
#   200,
#   1541260488796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Coldplay',
#   'Logged In',
#   'Sara',
#   'F',
#   2,
#   'Johnson',
#   298.762,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Shiver',
#   200,
#   1541260778796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Tom Petty And The Heartbreakers',
#   'Logged In',
#   'Sara',
#   'F',
#   3,
#   'Johnson',
#   183.01342,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'The Wild One_ Forever',
#   200,
#   1541261076796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Girl Talk',
#   'Logged In',
#   'Sara',
#   'F',
#   4,
#   'Johnson',
#   173.24363,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Give and Go',
#   200,
#   1541261259796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Florence + The Machine',
#   'Logged In',
#   'Sara',
#   'F',
#   5,
#   'Johnson',
#   258.55955,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Cosmic Love',
#   200,
#   1541261432796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Three Drives',
#   'Logged In',
#   'Sara',
#   'F',
#   6,
#   'Johnson',
#   411.6371,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Greece 2000',
#   200,
#   1541261690796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Jonas Brothers',
#   'Logged In',
#   'Sara',
#   'F',
#   7,
#   'Johnson',
#   192.36526,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Sorry',
#   200,
#   1541262101796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Tevin Campbell',
#   'Logged In',
#   'Sara',
#   'F',
#   8,
#   'Johnson',
#   293.04118,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Round And Round (Soul Mix Edit)',
#   200,
#   1541262293796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Sting',
#   'Logged In',
#   'Sara',
#   'F',
#   9,
#   'Johnson',
#   257.12281,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Windmills Of Your Mind',
#   200,
#   1541262586796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('The Champs',
#   'Logged In',
#   'Sara',
#   'F',
#   10,
#   'Johnson',
#   132.0224,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Tequila',
#   200,
#   1541262843796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('RÃ\x83Â¶yksopp',
#   'Logged In',
#   'Sara',
#   'F',
#   11,
#   'Johnson',
#   214.93506,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Poor Leno Jakatta Radio Mix',
#   200,
#   1541262975796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Avenged Sevenfold',
#   'Logged In',
#   'Sara',
#   'F',
#   12,
#   'Johnson',
#   312.11057,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Bat Country (Album Version)',
#   200,
#   1541263189796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  (None,
#   'Logged In',
#   'Sylvie',
#   'F',
#   0,
#   'Cruz',
#   None,
#   'free',
#   'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#   'GET',
#   'Home',
#   1540266185796,
#   210,
#   None,
#   200,
#   1541263390796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"',
#   10),
#  ('Sam Cooke',
#   'Logged In',
#   'Sara',
#   'F',
#   13,
#   'Johnson',
#   122.04363,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   "Ain't Misbehavin",
#   200,
#   1541263501796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Apulanta',
#   'Logged In',
#   'Sara',
#   'F',
#   14,
#   'Johnson',
#   219.53261,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Hallaa',
#   200,
#   1541263623796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Era',
#   'Logged In',
#   'Sara',
#   'F',
#   15,
#   'Johnson',
#   200.56771,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Cathar Rhythm',
#   200,
#   1541263842796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Klaus Badelt',
#   'Logged In',
#   'Sylvie',
#   'F',
#   1,
#   'Cruz',
#   128.62649,
#   'free',
#   'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#   'PUT',
#   'NextSong',
#   1540266185796,
#   210,
#   'Moonlight Serenade',
#   200,
#   1541264015796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"',
#   10),
#  ('Parov Stelar',
#   'Logged In',
#   'Sara',
#   'F',
#   16,
#   'Johnson',
#   281.5473,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'KissKiss',
#   200,
#   1541264042796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Florence + The Machine',
#   'Logged In',
#   'Lily',
#   'F',
#   0,
#   'Koch',
#   290.48118,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   199,
#   'Rabbit Heart (Raise It Up)',
#   200,
#   1541264282796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('De La Soul',
#   'Logged In',
#   'Sara',
#   'F',
#   17,
#   'Johnson',
#   221.72689,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Me_ Myself & I',
#   200,
#   1541264323796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Lil Wayne / T-Pain',
#   'Logged In',
#   'Sara',
#   'F',
#   18,
#   'Johnson',
#   244.58404,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Got Money',
#   200,
#   1541264544796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Cher',
#   'Logged In',
#   'Lily',
#   'F',
#   1,
#   'Koch',
#   167.41832,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   199,
#   'Milord',
#   200,
#   1541264572796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('Edge Of Dawn',
#   'Logged In',
#   'Lily',
#   'F',
#   2,
#   'Koch',
#   253.72689,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   199,
#   'Losing Ground',
#   200,
#   1541264739796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('The Black Keys',
#   'Logged In',
#   'Sara',
#   'F',
#   19,
#   'Johnson',
#   223.84281,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Elevator',
#   200,
#   1541264788796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Smokie Norful',
#   'Logged In',
#   'Lily',
#   'F',
#   3,
#   'Koch',
#   337.84118,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   199,
#   'I Need You Now (Build A Bridge Version)',
#   200,
#   1541264992796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('Adam Lambert',
#   'Logged In',
#   'Sara',
#   'F',
#   20,
#   'Johnson',
#   227.39546,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Whataya Want From Me',
#   200,
#   1541265011796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Pulp',
#   'Logged In',
#   'Sara',
#   'F',
#   21,
#   'Johnson',
#   208.95302,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Little Girl (With Blue Eyes)',
#   200,
#   1541265238796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Alliance Ethnik',
#   'Logged In',
#   'Lily',
#   'F',
#   4,
#   'Koch',
#   265.76934,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   199,
#   'Creil City',
#   200,
#   1541265329796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('Tricky',
#   'Logged In',
#   'Sara',
#   'F',
#   22,
#   'Johnson',
#   212.79302,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Ponderosa',
#   200,
#   1541265446796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('John Butler Trio',
#   'Logged In',
#   'Lily',
#   'F',
#   5,
#   'Koch',
#   223.68608,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   199,
#   'Betterman (full-length/album version)',
#   200,
#   1541265594796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('Culture Club',
#   'Logged In',
#   'Sara',
#   'F',
#   23,
#   'Johnson',
#   282.48771,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Believe (Demo)',
#   200,
#   1541265658796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('The Temper Trap',
#   'Logged In',
#   'Lily',
#   'F',
#   6,
#   'Koch',
#   192.67873,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   199,
#   'Fader',
#   200,
#   1541265817796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('La Mosca Tse-Tse',
#   'Logged In',
#   'Sara',
#   'F',
#   24,
#   'Johnson',
#   195.082,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Patadas En El Corazon',
#   200,
#   1541265940796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Cute Is What We Aim For',
#   'Logged In',
#   'Lily',
#   'F',
#   7,
#   'Koch',
#   201.22077,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   199,
#   'Finger Twist & Split (Album Version)',
#   200,
#   1541266009796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('Jack Johnson',
#   'Logged In',
#   'Sara',
#   'F',
#   25,
#   'Johnson',
#   236.72118,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Bubble Toes',
#   200,
#   1541266135796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Siriusmo',
#   'Logged In',
#   'Lily',
#   'F',
#   8,
#   'Koch',
#   272.61342,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   199,
#   'Simple',
#   200,
#   1541266210796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('Creedence Clearwater Revival',
#   'Logged In',
#   'Sara',
#   'F',
#   26,
#   'Johnson',
#   312.89424,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   "Feelin' Blue",
#   200,
#   1541266371796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Alberto Plaza',
#   'Logged In',
#   'Lily',
#   'F',
#   9,
#   'Koch',
#   271.3073,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   199,
#   'No Seas Cruel (vivo)',
#   200,
#   1541266482796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('Brand New',
#   'Logged In',
#   'Sara',
#   'F',
#   27,
#   'Johnson',
#   188.49914,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Not The Sun',
#   200,
#   1541266683796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Sean Lennon',
#   'Logged In',
#   'Lily',
#   'F',
#   10,
#   'Koch',
#   202.97098,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   199,
#   'Into The Sun',
#   200,
#   1541266753796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('K-OS',
#   'Logged In',
#   'Sara',
#   'F',
#   28,
#   'Johnson',
#   211.33016,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'EMCEE Murdah',
#   200,
#   1541266871796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Nana Caymmi',
#   'Logged In',
#   'Lily',
#   'F',
#   11,
#   'Koch',
#   251.0624,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   199,
#   'Acercate Mas (2000 Digital Remaster)',
#   200,
#   1541266955796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('Casino Versus Japan',
#   'Logged In',
#   'Sara',
#   'F',
#   29,
#   'Johnson',
#   86.30812,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Moonlupe',
#   200,
#   1541267082796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('the bird and the bee',
#   'Logged In',
#   'Sara',
#   'F',
#   30,
#   'Johnson',
#   281.23383,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Ray Gun',
#   200,
#   1541267168796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Skyforger',
#   'Logged In',
#   'Lily',
#   'F',
#   12,
#   'Koch',
#   38.94812,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   199,
#   "In the Yard of the Father's Son",
#   200,
#   1541267206796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('Bryan Ferry',
#   'Logged In',
#   'Lily',
#   'F',
#   13,
#   'Koch',
#   265.87383,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   199,
#   'Slave To Love (1999 Digital Remaster)',
#   200,
#   1541267244796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('The Black Keys',
#   'Logged In',
#   'Sara',
#   'F',
#   31,
#   'Johnson',
#   196.91057,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'All Hands Against His Own',
#   200,
#   1541267449796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Foxy Shazam',
#   'Logged In',
#   'Lily',
#   'F',
#   14,
#   'Koch',
#   201.74322,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   199,
#   'Wanna-be Angel (Album Version)',
#   200,
#   1541267509796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('The Ruts',
#   'Logged In',
#   'Sara',
#   'F',
#   32,
#   'Johnson',
#   338.96444,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'West One (Shine On Me)',
#   200,
#   1541267645796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ("Old 97's",
#   'Logged In',
#   'Lily',
#   'F',
#   15,
#   'Koch',
#   231.28771,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   199,
#   'Victoria (LP Version)',
#   200,
#   1541267710796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('Lonnie Gordon',
#   'Logged In',
#   'Lily',
#   'F',
#   16,
#   'Koch',
#   181.21098,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   199,
#   'Catch You Baby (Steve Pitron & Max Sanna Radio Edit)',
#   200,
#   1541267941796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('Bon Iver',
#   'Logged In',
#   'Sara',
#   'F',
#   33,
#   'Johnson',
#   220.70812,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'For Emma',
#   200,
#   1541267983796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Florence + The Machine',
#   'Logged In',
#   'Lily',
#   'F',
#   17,
#   'Koch',
#   219.66322,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   199,
#   'Dog Days Are Over (Radio Edit)',
#   200,
#   1541268122796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('Glen Washington',
#   'Logged In',
#   'Sara',
#   'F',
#   34,
#   'Johnson',
#   193.82812,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'One Of These Days',
#   200,
#   1541268203796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Mad Cobra',
#   'Logged In',
#   'Lily',
#   'F',
#   18,
#   'Koch',
#   230.68689,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   199,
#   'Flex',
#   200,
#   1541268341796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('Dropout Year',
#   'Logged In',
#   'Sara',
#   'F',
#   35,
#   'Johnson',
#   227.36934,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'This Notebook',
#   200,
#   1541268396796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Flogging Molly',
#   'Logged In',
#   'Lily',
#   'F',
#   19,
#   'Koch',
#   260.75383,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   199,
#   'Punch Drunk Grinning Soul',
#   200,
#   1541268571796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('Young Rebel Set',
#   'Logged In',
#   'Sara',
#   'F',
#   36,
#   'Johnson',
#   248.55465,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'If I Was',
#   200,
#   1541268623796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Sneaker Pimps',
#   'Logged In',
#   'Lily',
#   'F',
#   20,
#   'Koch',
#   260.91057,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   199,
#   'Spin Spin Sugar',
#   200,
#   1541268831796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('Righteous Brothers',
#   'Logged In',
#   'Sara',
#   'F',
#   37,
#   'Johnson',
#   215.90159,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Unchained Melody',
#   200,
#   1541268871796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Me First And The Gimme Gimmes',
#   'Logged In',
#   'Sara',
#   'F',
#   38,
#   'Johnson',
#   64.39138,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   "Jonny's Blessing",
#   200,
#   1541269086796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Texas In July',
#   'Logged In',
#   'Lily',
#   'F',
#   21,
#   'Koch',
#   190.69342,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   199,
#   'Aurora',
#   200,
#   1541269091796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('Alice In Chains',
#   'Logged In',
#   'Sara',
#   'F',
#   39,
#   'Johnson',
#   230.60853,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'God Smack',
#   200,
#   1541269150796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  (None,
#   'Logged In',
#   'Sara',
#   'F',
#   40,
#   'Johnson',
#   None,
#   'paid',
#   'Winston-Salem, NC',
#   'GET',
#   'Downgrade',
#   1540809153796,
#   152,
#   None,
#   200,
#   1541269220796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('10 Years',
#   'Logged In',
#   'Lily',
#   'F',
#   22,
#   'Koch',
#   229.95546,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   199,
#   'Wasteland',
#   200,
#   1541269281796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('Juanes',
#   'Logged In',
#   'Lily',
#   'F',
#   23,
#   'Koch',
#   233.40363,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   199,
#   'No Siento Penas',
#   200,
#   1541269510796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  (None,
#   'Logged In',
#   'Sara',
#   'F',
#   41,
#   'Johnson',
#   None,
#   'paid',
#   'Winston-Salem, NC',
#   'GET',
#   'Downgrade',
#   1540809153796,
#   152,
#   None,
#   200,
#   1541269515796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  (None,
#   'Logged In',
#   'Sara',
#   'F',
#   42,
#   'Johnson',
#   None,
#   'paid',
#   'Winston-Salem, NC',
#   'GET',
#   'Home',
#   1540809153796,
#   152,
#   None,
#   200,
#   1541269560796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Cat Stevens',
#   'Logged In',
#   'Sara',
#   'F',
#   43,
#   'Johnson',
#   200.202,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Wild World',
#   200,
#   1541269636796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Passion Pit',
#   'Logged In',
#   'Lily',
#   'F',
#   24,
#   'Koch',
#   174.75873,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   199,
#   'Sleepyhead',
#   200,
#   1541269743796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('The Temper Trap',
#   'Logged In',
#   'Sara',
#   'F',
#   44,
#   'Johnson',
#   192.67873,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Fader',
#   200,
#   1541269836796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('OneRepublic',
#   'Logged In',
#   'Lily',
#   'F',
#   25,
#   'Koch',
#   224.67873,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   199,
#   'Secrets',
#   200,
#   1541269917796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('Diplo',
#   'Logged In',
#   'Sara',
#   'F',
#   45,
#   'Johnson',
#   96.86159,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Florida',
#   200,
#   1541270028796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Afro Celt Sound System',
#   'Logged In',
#   'Sara',
#   'F',
#   46,
#   'Johnson',
#   425.01179,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Even In My Dreams',
#   200,
#   1541270124796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('PeterLicht',
#   'Logged In',
#   'Lily',
#   'F',
#   26,
#   'Koch',
#   306.80771,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   199,
#   'Heiterkeit',
#   200,
#   1541270141796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  (None,
#   'Logged In',
#   'Lily',
#   'F',
#   27,
#   'Koch',
#   None,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'GET',
#   'Downgrade',
#   1541048010796,
#   199,
#   None,
#   200,
#   1541270199796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('M.A. Numminen',
#   'Logged In',
#   'Sara',
#   'F',
#   47,
#   'Johnson',
#   166.55628,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'TULENLIEKKI',
#   200,
#   1541270549796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  (None,
#   'Logged In',
#   'Sara',
#   'F',
#   48,
#   'Johnson',
#   None,
#   'paid',
#   'Winston-Salem, NC',
#   'GET',
#   'Home',
#   1540809153796,
#   152,
#   None,
#   200,
#   1541270836796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Limp Bizkit',
#   'Logged In',
#   'Sara',
#   'F',
#   49,
#   'Johnson',
#   214.5171,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   "Rollin' (Air Raid Vehicle)",
#   200,
#   1541270854796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Downhere',
#   'Logged In',
#   'Sara',
#   'F',
#   50,
#   'Johnson',
#   230.71302,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'In America (Album Version)',
#   200,
#   1541271068796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Roots Manuva',
#   'Logged In',
#   'Sara',
#   'F',
#   51,
#   'Johnson',
#   233.92608,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'No Love',
#   200,
#   1541271298796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Lykke Li',
#   'Logged In',
#   'Sara',
#   'F',
#   52,
#   'Johnson',
#   162.19383,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Let It Fall',
#   200,
#   1541271531796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Plan B',
#   'Logged In',
#   'Sara',
#   'F',
#   53,
#   'Johnson',
#   222.82404,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Free',
#   200,
#   1541271693796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Octopus Project',
#   'Logged In',
#   'Sara',
#   'F',
#   54,
#   'Johnson',
#   498.33751,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Hypnopaedia',
#   200,
#   1541271915796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('OneRepublic',
#   'Logged In',
#   'Sara',
#   'F',
#   55,
#   'Johnson',
#   224.67873,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Secrets',
#   200,
#   1541272413796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Gilberto Santa Rosa',
#   'Logged In',
#   'Sara',
#   'F',
#   56,
#   'Johnson',
#   272.16934,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'La Sigo Amando Tanto',
#   200,
#   1541272637796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('Eric Clapton',
#   'Logged In',
#   'Sara',
#   'F',
#   57,
#   'Johnson',
#   271.80363,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Tears In Heaven',
#   200,
#   1541272909796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  ('ARRESTED DEVELOPMENT',
#   'Logged In',
#   'Sara',
#   'F',
#   58,
#   'Johnson',
#   200.98567,
#   'paid',
#   'Winston-Salem, NC',
#   'PUT',
#   'NextSong',
#   1540809153796,
#   152,
#   'Fountain Of Youth',
#   200,
#   1541273180796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  (None,
#   'Logged In',
#   'Sara',
#   'F',
#   59,
#   'Johnson',
#   None,
#   'paid',
#   'Winston-Salem, NC',
#   'GET',
#   'Home',
#   1540809153796,
#   152,
#   None,
#   200,
#   1541273268796,
#   '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"',
#   95),
#  (None,
#   'Logged In',
#   'Adler',
#   'M',
#   0,
#   'Barrera',
#   None,
#   'free',
#   'New York-Newark-Jersey City, NY-NJ-PA',
#   'GET',
#   'Home',
#   1540835983796,
#   248,
#   None,
#   200,
#   1541470364796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"',
#   100),
#  ('Gustavo Cerati',
#   'Logged In',
#   'Adler',
#   'M',
#   1,
#   'Barrera',
#   249.44281,
#   'free',
#   'New York-Newark-Jersey City, NY-NJ-PA',
#   'PUT',
#   'NextSong',
#   1540835983796,
#   248,
#   'Uno Entre 1000',
#   200,
#   1541470383796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"',
#   100),
#  ('Limp Bizkit',
#   'Logged In',
#   'Adler',
#   'M',
#   2,
#   'Barrera',
#   270.49751,
#   'free',
#   'New York-Newark-Jersey City, NY-NJ-PA',
#   'PUT',
#   'NextSong',
#   1540835983796,
#   248,
#   'Behind Blue Eyes',
#   200,
#   1541470632796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"',
#   100),
#  (None,
#   'Logged In',
#   'Samuel',
#   'M',
#   0,
#   'Gonzalez',
#   None,
#   'free',
#   'Houston-The Woodlands-Sugar Land, TX',
#   'GET',
#   'Home',
#   1540492941796,
#   252,
#   None,
#   200,
#   1541473967796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"',
#   61),
#  ('Mikel Erentxun',
#   'Logged In',
#   'Samuel',
#   'M',
#   1,
#   'Gonzalez',
#   178.83383,
#   'free',
#   'Houston-The Woodlands-Sugar Land, TX',
#   'PUT',
#   'NextSong',
#   1540492941796,
#   252,
#   'Frases Mudas',
#   200,
#   1541474048796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"',
#   61),
#  ('The Gerbils',
#   'Logged In',
#   'Martin',
#   'M',
#   0,
#   'Johnson',
#   27.01016,
#   'free',
#   'Minneapolis-St. Paul-Bloomington, MN-WI',
#   'PUT',
#   'NextSong',
#   1541081807796,
#   250,
#   '(iii)',
#   200,
#   1541480171796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"',
#   55),
#  ('AFI',
#   'Logged In',
#   'Martin',
#   'M',
#   1,
#   'Johnson',
#   190.45832,
#   'free',
#   'Minneapolis-St. Paul-Bloomington, MN-WI',
#   'PUT',
#   'NextSong',
#   1541081807796,
#   250,
#   "Girl's Not Grey",
#   200,
#   1541480198796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"',
#   55),
#  (None,
#   'Logged In',
#   'Jordan',
#   'F',
#   0,
#   'Hicks',
#   None,
#   'free',
#   'Salinas, CA',
#   'GET',
#   'Home',
#   1540008898796,
#   240,
#   None,
#   200,
#   1541480984796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"',
#   37),
#  ('Lhasa De Sela',
#   'Logged In',
#   'Jordan',
#   'F',
#   1,
#   'Hicks',
#   256.10404,
#   'free',
#   'Salinas, CA',
#   'PUT',
#   'NextSong',
#   1540008898796,
#   240,
#   'De cara a la pared',
#   200,
#   1541481077796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"',
#   37),
#  ('J.J. Cale',
#   'Logged In',
#   'Jordan',
#   'F',
#   2,
#   'Hicks',
#   150.80444,
#   'free',
#   'Salinas, CA',
#   'PUT',
#   'NextSong',
#   1540008898796,
#   240,
#   'Crazy Mama',
#   200,
#   1541481333796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"',
#   37),
#  ('Brian Eno',
#   'Logged In',
#   'Jordan',
#   'F',
#   3,
#   'Hicks',
#   265.82159,
#   'free',
#   'Salinas, CA',
#   'PUT',
#   'NextSong',
#   1540008898796,
#   240,
#   'An Ending (Ascent) (2005 Digital Remaster)',
#   200,
#   1541481483796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"',
#   37),
#  ('Hot Hot Heat',
#   'Logged In',
#   'Jordan',
#   'F',
#   4,
#   'Hicks',
#   190.01424,
#   'free',
#   'Salinas, CA',
#   'PUT',
#   'NextSong',
#   1540008898796,
#   240,
#   'Soldier In A Box (Album Version)',
#   200,
#   1541481748796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"',
#   37),
#  (None,
#   'Logged In',
#   'Lily',
#   'F',
#   0,
#   'Burns',
#   None,
#   'free',
#   'New York-Newark-Jersey City, NY-NJ-PA',
#   'GET',
#   'Home',
#   1540621059796,
#   287,
#   None,
#   200,
#   1541483351796,
#   '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"',
#   32),
#  ('ATB',
#   'Logged In',
#   'Ryan',
#   'M',
#   0,
#   'Smith',
#   209.26649,
#   'free',
#   'San Jose-Sunnyvale-Santa Clara, CA',
#   'PUT',
#   'NextSong',
#   1541016707796,
#   278,
#   "You're Not Alone",
#   200,
#   1541484351796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   26),
#  (None,
#   'Logged In',
#   'Tegan',
#   'F',
#   0,
#   'Levine',
#   None,
#   'free',
#   'Portland-South Portland, ME',
#   'GET',
#   'Home',
#   1540794356796,
#   279,
#   None,
#   200,
#   1541484363796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"',
#   80),
#  ('Mt. St. Helens Vietnam Band',
#   'Logged In',
#   'Ryan',
#   'M',
#   1,
#   'Smith',
#   253.6224,
#   'free',
#   'San Jose-Sunnyvale-Santa Clara, CA',
#   'PUT',
#   'NextSong',
#   1541016707796,
#   278,
#   'A Year Or Two',
#   200,
#   1541484560796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   26),
#  ('Becky',
#   'Logged In',
#   'Ryan',
#   'M',
#   2,
#   'Smith',
#   245.62893,
#   'free',
#   'San Jose-Sunnyvale-Santa Clara, CA',
#   'PUT',
#   'NextSong',
#   1541016707796,
#   278,
#   'Kimi e',
#   200,
#   1541484813796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   26),
#  ('Franz Ferdinand',
#   'Logged In',
#   'Ryan',
#   'M',
#   3,
#   'Smith',
#   254.69342,
#   'free',
#   'San Jose-Sunnyvale-Santa Clara, CA',
#   'PUT',
#   'NextSong',
#   1541016707796,
#   278,
#   'This Fire',
#   200,
#   1541485058796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   26),
#  ('Creedence Clearwater Revival',
#   'Logged In',
#   'Ryan',
#   'M',
#   4,
#   'Smith',
#   230.94812,
#   'free',
#   'San Jose-Sunnyvale-Santa Clara, CA',
#   'PUT',
#   'NextSong',
#   1541016707796,
#   278,
#   "It's Just A Thought",
#   200,
#   1541485312796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   26),
#  ('Paul Stanley',
#   'Logged In',
#   'Tegan',
#   'F',
#   1,
#   'Levine',
#   187.32363,
#   'free',
#   'Portland-South Portland, ME',
#   'PUT',
#   'NextSong',
#   1540794356796,
#   279,
#   'Live To Win',
#   200,
#   1541485351796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"',
#   80),
#  ('Benga',
#   'Logged In',
#   'Kevin',
#   'M',
#   0,
#   'Arellano',
#   314.64444,
#   'free',
#   'Harrisburg-Carlisle, PA',
#   'PUT',
#   'NextSong',
#   1540006905796,
#   191,
#   'Pleasure',
#   200,
#   1541489492796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"',
#   66),
#  ('Basshunter',
#   'Logged In',
#   'Kevin',
#   'M',
#   1,
#   'Arellano',
#   190.17098,
#   'free',
#   'Harrisburg-Carlisle, PA',
#   'PUT',
#   'NextSong',
#   1540006905796,
#   191,
#   'Why',
#   200,
#   1541489806796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"',
#   66),
#  ('Kings Of Leon',
#   'Logged In',
#   'Kevin',
#   'M',
#   2,
#   'Arellano',
#   231.81016,
#   'free',
#   'Harrisburg-Carlisle, PA',
#   'PUT',
#   'NextSong',
#   1540006905796,
#   191,
#   'Use Somebody',
#   200,
#   1541489996796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"',
#   66),
#  ('Slim Dusty',
#   'Logged In',
#   'Austin',
#   'M',
#   0,
#   'Rosales',
#   198.922,
#   'free',
#   'New York-Newark-Jersey City, NY-NJ-PA',
#   'PUT',
#   'NextSong',
#   1541059521796,
#   300,
#   'Long Black Road',
#   200,
#   1541494159796,
#   'Mozilla/5.0 (Windows NT 6.1; rv:31.0) Gecko/20100101 Firefox/31.0',
#   12),
#  (None,
#   'Logged In',
#   'Ryan',
#   'M',
#   0,
#   'Smith',
#   None,
#   'free',
#   'San Jose-Sunnyvale-Santa Clara, CA',
#   'GET',
#   'Home',
#   1541016707796,
#   306,
#   None,
#   200,
#   1541496567796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   26),
#  ('Dido',
#   'Logged In',
#   'Celeste',
#   'F',
#   0,
#   'Williams',
#   235.57179,
#   'free',
#   'Klamath Falls, OR',
#   'PUT',
#   'NextSong',
#   1541077528796,
#   215,
#   "I'm No Angel",
#   200,
#   1541498691796,
#   '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.103 Safari/537.36"',
#   53),
#  ('Lifehouse',
#   'Logged In',
#   'Celeste',
#   'F',
#   1,
#   'Williams',
#   195.47383,
#   'free',
#   'Klamath Falls, OR',
#   'PUT',
#   'NextSong',
#   1541077528796,
#   215,
#   'You And Me (Wedding Version)',
#   200,
#   1541498926796,
#   '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.103 Safari/537.36"',
#   53),
#  ('Gary U.S. Bonds',
#   'Logged In',
#   'Celeste',
#   'F',
#   2,
#   'Williams',
#   243.25179,
#   'free',
#   'Klamath Falls, OR',
#   'PUT',
#   'NextSong',
#   1541077528796,
#   215,
#   'Angelyne',
#   200,
#   1541499121796,
#   '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.103 Safari/537.36"',
#   53),
#  ('Throw Me The Statue',
#   'Logged In',
#   'Celeste',
#   'F',
#   3,
#   'Williams',
#   189.85751,
#   'free',
#   'Klamath Falls, OR',
#   'PUT',
#   'NextSong',
#   1541077528796,
#   215,
#   'Noises',
#   200,
#   1541499364796,
#   '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.103 Safari/537.36"',
#   53),
#  ('Steely Dan',
#   'Logged In',
#   'Mohammad',
#   'M',
#   0,
#   'Rodriguez',
#   457.89995,
#   'free',
#   'Sacramento--Roseville--Arden-Arcade, CA',
#   'PUT',
#   'NextSong',
#   1540511766796,
#   206,
#   'Deacon Blues',
#   200,
#   1541505185796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"',
#   88),
#  (None,
#   'Logged In',
#   'Ava',
#   'F',
#   0,
#   'Robinson',
#   None,
#   'free',
#   'New Haven-Milford, CT',
#   'GET',
#   'Home',
#   1540931983796,
#   211,
#   None,
#   200,
#   1541509101796,
#   '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"',
#   50),
#  ('Arctic Monkeys',
#   'Logged In',
#   'Ava',
#   'F',
#   1,
#   'Robinson',
#   191.26812,
#   'free',
#   'New Haven-Milford, CT',
#   'PUT',
#   'NextSong',
#   1540931983796,
#   211,
#   'Old Yellow Bricks',
#   200,
#   1541509129796,
#   '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"',
#   50),
#  ('Sade',
#   'Logged In',
#   'Ava',
#   'F',
#   2,
#   'Robinson',
#   271.96036,
#   'free',
#   'New Haven-Milford, CT',
#   'PUT',
#   'NextSong',
#   1540931983796,
#   211,
#   'Hang On To Your Love',
#   200,
#   1541509320796,
#   '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"',
#   50),
#  (None,
#   'Logged In',
#   'Ava',
#   'F',
#   3,
#   'Robinson',
#   None,
#   'free',
#   'New Haven-Milford, CT',
#   'GET',
#   'Home',
#   1540931983796,
#   211,
#   None,
#   200,
#   1541509428796,
#   '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"',
#   50),
#  ('Florence + The Machine',
#   'Logged In',
#   'Bronson',
#   'M',
#   0,
#   'Harris',
#   219.66322,
#   'free',
#   'Eugene, OR',
#   'PUT',
#   'NextSong',
#   1540906915796,
#   251,
#   'Dog Days Are Over (Radio Edit)',
#   200,
#   1541512300796,
#   '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"',
#   33),
#  (None,
#   'Logged In',
#   'Rylan',
#   'M',
#   0,
#   'George',
#   None,
#   'free',
#   'Birmingham-Hoover, AL',
#   'GET',
#   'About',
#   1541020249796,
#   233,
#   None,
#   200,
#   1541512431796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"',
#   16),
#  (None,
#   'Logged In',
#   'Maia',
#   'F',
#   0,
#   'Burke',
#   None,
#   'free',
#   'Houston-The Woodlands-Sugar Land, TX',
#   'GET',
#   'Home',
#   1540676534796,
#   230,
#   None,
#   200,
#   1541514106796,
# ...
#   15),
#  ('Rionegro / SolimÃ\x83Âµes',
#   'Logged In',
#   'Lily',
#   'F',
#   62,
#   'Koch',
#   280.92036,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   172,
#   'De SÃ\x83Â£o Paulo Ã\x83Â\x80 BelÃ\x83Â©m',
#   200,
#   1541163717796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('Drive-By Truckers',
#   'Logged In',
#   'Lily',
#   'F',
#   63,
#   'Koch',
#   246.22975,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   172,
#   'Outfit',
#   200,
#   1541163997796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('The Academy Is...',
#   'Logged In',
#   'Layla',
#   'F',
#   9,
#   'Griffin',
#   209.76281,
#   'paid',
#   'Lake Havasu City-Kingman, AZ',
#   'PUT',
#   'NextSong',
#   1541057188796,
#   23,
#   'Paper Chase (Album Version)',
#   200,
#   1541431670796,
#   '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"',
#   24),
#  ('The Prodigy',
#   'Logged In',
#   'Kate',
#   'F',
#   7,
#   'Harrell',
#   414.11873,
#   'paid',
#   'Lansing-East Lansing, MI',
#   'PUT',
#   'NextSong',
#   1540472624796,
#   147,
#   'Weather Experience (Top Buzz Remix)(Remastered)',
#   200,
#   1541431749796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"',
#   97),
#  ('Bill Withers',
#   'Logged In',
#   'Aleena',
#   'F',
#   85,
#   'Kirby',
#   383.73832,
#   'paid',
#   'Waterloo-Cedar Falls, IA',
#   'PUT',
#   'NextSong',
#   1541022995796,
#   269,
#   'Make Love To Your Mind',
#   200,
#   1541431761796,
#   'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0',
#   44),
#  ('Dwight Yoakam',
#   'Logged In',
#   'Layla',
#   'F',
#   10,
#   'Griffin',
#   239.3073,
#   'paid',
#   'Lake Havasu City-Kingman, AZ',
#   'PUT',
#   'NextSong',
#   1541057188796,
#   23,
#   "You're The One",
#   200,
#   1541431879796,
#   '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"',
#   24),
#  ('The Far East Movement featuring Wiz Khalifa and Bionik',
#   'Logged In',
#   'Layla',
#   'F',
#   11,
#   'Griffin',
#   265.50812,
#   'paid',
#   'Lake Havasu City-Kingman, AZ',
#   'PUT',
#   'NextSong',
#   1541057188796,
#   23,
#   'Lowridin',
#   200,
#   1541432118796,
#   '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"',
#   24),
#  ('Deep Dish',
#   'Logged In',
#   'Kate',
#   'F',
#   8,
#   'Harrell',
#   439.92771,
#   'paid',
#   'Lansing-East Lansing, MI',
#   'PUT',
#   'NextSong',
#   1540472624796,
#   147,
#   'Sacramento (Club Mix Edit)',
#   200,
#   1541432163796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"',
#   97),
#  ('Amon Amarth',
#   'Logged In',
#   'Layla',
#   'F',
#   12,
#   'Griffin',
#   238.52363,
#   'paid',
#   'Lake Havasu City-Kingman, AZ',
#   'PUT',
#   'NextSong',
#   1541057188796,
#   23,
#   'The Hero',
#   200,
#   1541432383796,
#   '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"',
#   24),
#  ('Jim White',
#   'Logged In',
#   'Kate',
#   'F',
#   9,
#   'Harrell',
#   396.22485,
#   'paid',
#   'Lansing-East Lansing, MI',
#   'PUT',
#   'NextSong',
#   1540472624796,
#   147,
#   'Still Waters',
#   200,
#   1541432602796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"',
#   97),
#  ('Modest Mouse',
#   'Logged In',
#   'Layla',
#   'F',
#   13,
#   'Griffin',
#   259.47383,
#   'paid',
#   'Lake Havasu City-Kingman, AZ',
#   'PUT',
#   'NextSong',
#   1541057188796,
#   23,
#   'The Good Times Are Killing Me',
#   200,
#   1541432621796,
#   '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"',
#   24),
#  ('Bad Company',
#   'Logged In',
#   'Layla',
#   'F',
#   14,
#   'Griffin',
#   246.96118,
#   'paid',
#   'Lake Havasu City-Kingman, AZ',
#   'PUT',
#   'NextSong',
#   1541057188796,
#   23,
#   'Morning Sun',
#   200,
#   1541432880796,
#   '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"',
#   24),
#  (None,
#   'Logged In',
#   'Layla',
#   'F',
#   15,
#   'Griffin',
#   None,
#   'paid',
#   'Lake Havasu City-Kingman, AZ',
#   'GET',
#   'Settings',
#   1541057188796,
#   23,
#   None,
#   200,
#   1541432938796,
#   '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"',
#   24),
#  ('Five Iron Frenzy',
#   'Logged In',
#   'Kate',
#   'F',
#   10,
#   'Harrell',
#   236.09424,
#   'paid',
#   'Lansing-East Lansing, MI',
#   'PUT',
#   'NextSong',
#   1540472624796,
#   147,
#   'Canada',
#   200,
#   1541432998796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"',
#   97),
#  ('Bodyrox',
#   'Logged In',
#   'Layla',
#   'F',
#   16,
#   'Griffin',
#   490.78812,
#   'paid',
#   'Lake Havasu City-Kingman, AZ',
#   'PUT',
#   'NextSong',
#   1541057188796,
#   23,
#   'Yeah Yeah',
#   200,
#   1541433126796,
#   '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"',
#   24),
#  ('Louise Attaque',
#   'Logged In',
#   'Kate',
#   'F',
#   11,
#   'Harrell',
#   177.76281,
#   'paid',
#   'Lansing-East Lansing, MI',
#   'PUT',
#   'NextSong',
#   1540472624796,
#   147,
#   "Est-ce que tu m'aimes encore ?",
#   200,
#   1541433234796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"',
#   97),
#  (None,
#   'Logged In',
#   'Sylvie',
#   'F',
#   0,
#   'Cruz',
#   None,
#   'free',
#   'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#   'GET',
#   'Home',
#   1540266185796,
#   272,
#   None,
#   200,
#   1541433408796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"',
#   10),
#  ('The Pussycat Dolls / Busta Rhymes',
#   'Logged In',
#   'Kate',
#   'F',
#   12,
#   'Harrell',
#   272.14322,
#   'paid',
#   'Lansing-East Lansing, MI',
#   'PUT',
#   'NextSong',
#   1540472624796,
#   147,
#   "Don't Cha",
#   200,
#   1541433411796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"',
#   97),
#  ('Thursday',
#   'Logged In',
#   'Jacob',
#   'M',
#   0,
#   'Klein',
#   250.17424,
#   'paid',
#   'Tampa-St. Petersburg-Clearwater, FL',
#   'PUT',
#   'NextSong',
#   1540558108796,
#   255,
#   'Signals Over The Air',
#   200,
#   1541433477796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"',
#   73),
#  ('Alberto Plaza',
#   'Logged In',
#   'Layla',
#   'F',
#   17,
#   'Griffin',
#   291.5522,
#   'paid',
#   'Lake Havasu City-Kingman, AZ',
#   'PUT',
#   'NextSong',
#   1541057188796,
#   23,
#   'Yo Te Seguire (vivo)',
#   200,
#   1541433616796,
#   '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"',
#   24),
#  ('Amy Winehouse',
#   'Logged In',
#   'Sylvie',
#   'F',
#   1,
#   'Cruz',
#   202.73587,
#   'free',
#   'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#   'PUT',
#   'NextSong',
#   1540266185796,
#   272,
#   "You Know I'm No Good",
#   200,
#   1541433665796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.77.4 (KHTML, like Gecko) Version/7.0.5 Safari/537.77.4"',
#   10),
#  ('Musiq / DJ Aktive / Carol Riddick',
#   'Logged In',
#   'Kate',
#   'F',
#   13,
#   'Harrell',
#   162.7424,
#   'paid',
#   'Lansing-East Lansing, MI',
#   'PUT',
#   'NextSong',
#   1540472624796,
#   147,
#   'Soulstar',
#   200,
#   1541433683796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"',
#   97),
#  ('Eels',
#   'Logged In',
#   'Jacob',
#   'M',
#   1,
#   'Klein',
#   193.27955,
#   'paid',
#   'Tampa-St. Petersburg-Clearwater, FL',
#   'PUT',
#   'NextSong',
#   1540558108796,
#   255,
#   'Guest List',
#   200,
#   1541433727796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"',
#   73),
#  ('Dwight Yoakam',
#   'Logged In',
#   'Kate',
#   'F',
#   14,
#   'Harrell',
#   239.3073,
#   'paid',
#   'Lansing-East Lansing, MI',
#   'PUT',
#   'NextSong',
#   1540472624796,
#   147,
#   "You're The One",
#   200,
#   1541433845796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"',
#   97),
#  ('matchbox twenty',
#   'Logged In',
#   'Layla',
#   'F',
#   18,
#   'Griffin',
#   225.95873,
#   'paid',
#   'Lake Havasu City-Kingman, AZ',
#   'PUT',
#   'NextSong',
#   1541057188796,
#   23,
#   '3AM (LP Version)',
#   200,
#   1541433907796,
#   '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"',
#   24),
#  ('Coldplay',
#   'Logged In',
#   'Jacob',
#   'M',
#   2,
#   'Klein',
#   311.27465,
#   'paid',
#   'Tampa-St. Petersburg-Clearwater, FL',
#   'PUT',
#   'NextSong',
#   1540558108796,
#   255,
#   'The Scientist',
#   200,
#   1541433920796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"',
#   73),
#  ('Scissor Sisters',
#   'Logged In',
#   'Kate',
#   'F',
#   15,
#   'Harrell',
#   271.85587,
#   'paid',
#   'Lansing-East Lansing, MI',
#   'PUT',
#   'NextSong',
#   1540472624796,
#   147,
#   'Take Your Mama',
#   200,
#   1541434084796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"',
#   97),
#  ('Rob Zombie',
#   'Logged In',
#   'Layla',
#   'F',
#   19,
#   'Griffin',
#   222.9024,
#   'paid',
#   'Lake Havasu City-Kingman, AZ',
#   'PUT',
#   'NextSong',
#   1541057188796,
#   23,
#   'Dragula',
#   200,
#   1541434132796,
#   '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"',
#   24),
#  ('Tweet',
#   'Logged In',
#   'Lily',
#   'F',
#   64,
#   'Koch',
#   256.39138,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   172,
#   'Smoking Cigarettes (LP Version)',
#   200,
#   1541164243796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('Ben Folds Five',
#   'Logged In',
#   'Lily',
#   'F',
#   65,
#   'Koch',
#   207.882,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   172,
#   "Steven's Last Night In Town",
#   200,
#   1541164499796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('Glen Hansard',
#   'Logged In',
#   'Lily',
#   'F',
#   66,
#   'Koch',
#   239.59465,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   172,
#   'Lies',
#   200,
#   1541164706796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('Chevelle',
#   'Logged In',
#   'Adler',
#   'M',
#   0,
#   'Barrera',
#   389.85098,
#   'free',
#   'New York-Newark-Jersey City, NY-NJ-PA',
#   'PUT',
#   'NextSong',
#   1540835983796,
#   174,
#   'Dos (LP Version)',
#   200,
#   1541164749796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"',
#   100),
#  ('Bill Withers',
#   'Logged In',
#   'Lily',
#   'F',
#   67,
#   'Koch',
#   383.73832,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   172,
#   'Make Love To Your Mind',
#   200,
#   1541164945796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('Jorge Drexler',
#   'Logged In',
#   'Adler',
#   'M',
#   1,
#   'Barrera',
#   272.14322,
#   'free',
#   'New York-Newark-Jersey City, NY-NJ-PA',
#   'PUT',
#   'NextSong',
#   1540835983796,
#   174,
#   'Salvapantallas',
#   200,
#   1541165138796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"',
#   100),
#  ('Michael Bolton',
#   'Logged In',
#   'Lily',
#   'F',
#   68,
#   'Koch',
#   255.65995,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   172,
#   'How Am I Supposed To Live Without You',
#   200,
#   1541165328796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('The Mercury Program',
#   'Logged In',
#   'Adler',
#   'M',
#   2,
#   'Barrera',
#   449.12281,
#   'free',
#   'New York-Newark-Jersey City, NY-NJ-PA',
#   'PUT',
#   'NextSong',
#   1540835983796,
#   174,
#   'Marianas',
#   200,
#   1541165410796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"',
#   100),
#  ('Duran Duran',
#   'Logged In',
#   'Lily',
#   'F',
#   69,
#   'Koch',
#   321.88036,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   172,
#   'The Seventh Stranger',
#   200,
#   1541165583796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('Little Boots',
#   'Logged In',
#   'Lily',
#   'F',
#   70,
#   'Koch',
#   195.94404,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   172,
#   'Meddle',
#   200,
#   1541165904796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('Johnossi',
#   'Logged In',
#   'Lily',
#   'F',
#   71,
#   'Koch',
#   174.2624,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   172,
#   'Glory Days To Come',
#   200,
#   1541166099796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('BjÃ\x83Â¶rk',
#   'Logged In',
#   'Lily',
#   'F',
#   72,
#   'Koch',
#   348.57751,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   172,
#   'Undo',
#   200,
#   1541166273796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('Black Eyed Peas',
#   'Logged In',
#   'Lily',
#   'F',
#   73,
#   'Koch',
#   226.37669,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   172,
#   'Hey Mama',
#   200,
#   1541166621796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('DecembeRadio',
#   'Logged In',
#   'Lily',
#   'F',
#   74,
#   'Koch',
#   249.62567,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   172,
#   'Find You Waiting',
#   200,
#   1541166847796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  ('Bonobo',
#   'Logged In',
#   'Lily',
#   'F',
#   75,
#   'Koch',
#   270.41914,
#   'paid',
#   'Chicago-Naperville-Elgin, IL-IN-WI',
#   'PUT',
#   'NextSong',
#   1541048010796,
#   172,
#   '1009',
#   200,
#   1541167096796,
#   '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"',
#   15),
#  (None,
#   'Logged In',
#   'Tegan',
#   'F',
#   0,
#   'Levine',
#   None,
#   'free',
#   'Portland-South Portland, ME',
#   'GET',
#   'Home',
#   1540794356796,
#   194,
#   None,
#   200,
#   1541168424796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"',
#   80),
#  ('Five Iron Frenzy',
#   'Logged In',
#   'Tegan',
#   'F',
#   1,
#   'Levine',
#   236.09424,
#   'free',
#   'Portland-South Portland, ME',
#   'PUT',
#   'NextSong',
#   1540794356796,
#   194,
#   'Canada',
#   200,
#   1541168577796,
#   '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"',
#   80),
#  ...]

# %%
cur.execute("""
    copy songs from 's3://udacity-dend/song_data'
    credentials 'aws_iam_role={}'
    json 'auto'
    region 'us-west-2';
""".format(DWH_ROLE_ARN)
)
cur.fetchall()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[58], line 8
#       1 cur.execute("""
#       2     copy songs from 's3://udacity-dend/song_data'
#       3     credentials 'aws_iam_role={}'
#    (...)
#       6 """.format(DWH_ROLE_ARN)
#       7 )
# ----> 8 cur.fetchall()
#
# ProgrammingError: no results to fetch

# %%
cur.execute("""
COPY song_events FROM 's3://udacity-dend/log_data' 
    CREDENTIALS 'aws_iam_role={}'
    JSON 's3://udacity-dend/log_json_path.json'
    REGION 'us-west-2';
""".format(DWH_ROLE_ARN)
)
cur.fetchall()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[52], line 8
#       1 cur.execute("""
#       2 COPY song_events FROM 's3://udacity-dend/log_data'
#       3     CREDENTIALS 'aws_iam_role={}'
#    (...)
#       6 """.format(DWH_ROLE_ARN)
#       7 )
# ----> 8 cur.fetchall()
#
# ProgrammingError: no results to fetch

# %%
import boto3

s3 = boto3.resource('s3',
                       region_name="us-west-2",
                       aws_access_key_id=KEY,
                       aws_secret_access_key=SECRET
                     )

sampleDbBucket =  s3.Bucket("udacity-dend")

for obj in sampleDbBucket.objects.filter(Prefix="song_data"):
    print(obj)
# Out:
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAAAK128F9318786.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAAAV128F421A322.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAABD128F429CF47.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAACN128F9355673.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAAEA128F935A30D.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAAED128E0783FAB.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAAEM128F93347B9.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAAEW128F42930C0.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAAFD128F92F423A.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAAGR128F425B14B.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAAHD128F42635A5.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAAHJ128F931194C.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAAHZ128E0799171.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAAIR128F1480971.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAAJN128F428E437.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAAND12903CD1F1B.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAANK128F428B515.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAAOF128F429C156.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAAPK128E0786D96.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAAQN128F9353BA0.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAAQO12903CD8E1C.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAAUC128F428716F.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAAUR128F428B1FA.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAAYL128F4271A5B.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/B/TRAABCL128F4286650.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/B/TRAABDL12903CAABBA.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/B/TRAABEV12903CC53A4.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/B/TRAABFH128F92C812E.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/B/TRAABGU12903CC8DCF.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/B/TRAABHB12903CAFC2F.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/B/TRAABHO12903D08576.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/B/TRAABHP128F427AEC8.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/B/TRAABIG128F9356C56.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/B/TRAABIX128F92D6F94.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/B/TRAABJS128F9325C99.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/B/TRAABKD128F9302CE9.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/B/TRAABLR128F423B7E3.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/B/TRAABNV128F425CEE1.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/B/TRAABOA128F933684A.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/B/TRAABOG128F42955B1.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/B/TRAABPG128F14774DD.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/B/TRAABPO128F9312A56.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/B/TRAABPQ128F428F0B0.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/B/TRAABRX12903CC4816.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/B/TRAABTB128F146BF24.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/B/TRAABUQ128F92ECD79.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/B/TRAABVM128F14970CA.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/B/TRAABVM128F92CA9DC.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/B/TRAABWH128F427ABE8.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/B/TRAABXA128F9326351.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/C/TRAACAS128F4216F17.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/C/TRAACCD128F422CDA8.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/C/TRAACCG128F92E8A55.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/C/TRAACEI128F930C60E.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/C/TRAACER128F4290F96.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/C/TRAACIC128F427BFD7.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/C/TRAACIE128F428495B.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/C/TRAACIR128F42963AC.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/C/TRAACJC128F934ABB5.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/C/TRAACKM12903CE5BE9.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/C/TRAACLF128F1461E73.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/C/TRAACLG128F4276511.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/C/TRAACLV128F427E123.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/C/TRAACMJ128F930C704.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/C/TRAACPH12903CF5F14.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/C/TRAACQT128F9331780.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/C/TRAACRY12903CAF2C2.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/C/TRAACSL128F93462F4.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/C/TRAACUP128E0789C69.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/C/TRAACZN128F93236B1.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/C/TRAACZR12903CDD291.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/C/TRAACZX12903CE40E3.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADBN128F932D00A.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADCQ128F932EC14.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADDS128F425C68B.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADEB128F9335868.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADED128F42741FD.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADHC128F4227F6B.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADHS128F932C5ED.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADIN128F931D672.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADJU128F92F58E1.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADKA12903CD2511.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADKW128E079503A.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADKZ128F149BDFF.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADLH12903CA70EE.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADLN128F14832E9.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADLX128F1469250.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADMH128F9343E59.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADNL128F14519DF.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADNN128F42B1D94.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADQL128F427D281.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADQW128F427CE68.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADQX128F422B4CF.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADSH128F425C38D.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADVH128EF34DE7A.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADVO128E07999E9.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADXK12903CFAE92.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADXQ128F92FEEAE.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADYA128F92DFD1A.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADYB128F92D7E73.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADYI128E078FB38.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/D/TRAADZE12903CA6C8C.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/E/TRAAEDA12903CA1EFC.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/E/TRAAEDF128F930CC0F.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/E/TRAAEDJ12903CCE390.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/E/TRAAEDY12903CBBFA7.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/E/TRAAEEH128E0795DFE.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/E/TRAAEEO128F4288E88.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/E/TRAAEHK128F92C9C79.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/E/TRAAEHW128F9344FD3.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/E/TRAAEJH128E0785506.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/E/TRAAEJV128F423CF04.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/E/TRAAELR128F42900A1.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/E/TRAAENC128F1451DE9.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/E/TRAAENM128EF33EDAA.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/E/TRAAEOT128F14681B9.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/E/TRAAEPG128F429139A.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/E/TRAAERS128F14A5562.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/E/TRAAERZ128F1496921.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/E/TRAAESC128EF36760E.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/E/TRAAETB12903CE8EF9.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/E/TRAAETC12903CC4839.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/E/TRAAETX128F4247A15.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/E/TRAAEVH128F1478FDC.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/E/TRAAEWG128F930B3A4.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/F/TRAAFBP128F92D4546.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/F/TRAAFDF128F42494A2.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/F/TRAAFDU128F426E91A.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/F/TRAAFEI128F422D353.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/F/TRAAFEU128E078581C.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/F/TRAAFFI128F4258B77.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/F/TRAAFFR128F42719EA.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/F/TRAAFGQ128F427D884.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/F/TRAAFHL128F933386A.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/F/TRAAFHY12903CB3BB3.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/F/TRAAFJW128F428A424.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/F/TRAAFLH128F42470B4.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/F/TRAAFML128F1451AF1.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/F/TRAAFOC128F4259332.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/F/TRAAFOH128E078BD7E.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/F/TRAAFON128F42926FB.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/F/TRAAFOR128F9343E60.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/F/TRAAFOY128F146CC17.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/F/TRAAFQF128F92F8770.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/F/TRAAFRM128F9320F58.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/F/TRAAFRU128F9339158.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/F/TRAAFRY128F92FDD5D.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/F/TRAAFSM128F425A2C5.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/F/TRAAFTE128F429545F.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/F/TRAAFXR128F14858CB.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/F/TRAAFYL128E07856A7.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/F/TRAAFZI128E0793205.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/G/TRAAGAM128F428DCBE.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/G/TRAAGAM128F930D210.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/G/TRAAGAV128F4241242.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/G/TRAAGAY128F423CD9B.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/G/TRAAGBF128F4224629.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/G/TRAAGCG128F421CC9F.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/G/TRAAGCZ128F93210FD.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/G/TRAAGHB128F426AD7E.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/G/TRAAGIK128F4296CC2.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/G/TRAAGKB128F1480698.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/G/TRAAGKF128F932D5A2.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/G/TRAAGMC128F4292D0F.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/G/TRAAGMZ128EF34741A.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/G/TRAAGNS128E07824BD.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/G/TRAAGOC128F425C5AE.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/G/TRAAGPJ128F428CD1B.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/G/TRAAGQD128F92D2359.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/G/TRAAGRA128F9309CC9.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/G/TRAAGRF12903CE3D65.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/G/TRAAGSG128F92CFC6E.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/G/TRAAGVF128E0789785.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/G/TRAAGWD128F146C731.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/G/TRAAGWV12903CF3709.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/G/TRAAGXU12903C9BE30.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHAF12903CE61A7.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHBS128F429F76A.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHBU12903CB9E27.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHCO128F14B0844.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHDK128F423BB26.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHDQ128F4271B7D.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHEG128E07861C3.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHEL128F932FBA5.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHER128F424E6F3.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHER128F92D0354.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHHZ128F429B6E5.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHKE128F93053B2.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHMD12903D034F4.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHMO128F92DE7C9.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHOA128F425A4F7.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHPF128F424091D.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHPS128F4256DE9.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHPY12903CBD4AE.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHRF128F92FE234.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHSL128F42A0034.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHSY128F147BB5C.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHTB128EF348C94.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHTO128F93380A3.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHUO128F93533C9.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHVW128F149005E.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHVY128F92E25D6.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHYI12903CD4ED2.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHYK128F932A08F.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHYU12903CA92C2.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHYV128F932A425.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHYY128F4273BFE.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/H/TRAAHZP12903CA25F4.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/I/TRAAIAE128F42AC53D.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/I/TRAAIBB12903CECB35.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/I/TRAAIBM128F1497BC4.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/I/TRAAIBP128F1494936.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/I/TRAAICC12903CE71A7.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/I/TRAAICW128F1496C68.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/I/TRAAIDR128F145A5C2.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/I/TRAAIHF128F426FFA8.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/I/TRAAIHL128F92E6DDA.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/I/TRAAIII128F427D5D8.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/I/TRAAIKA128F426D3BB.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/I/TRAAIKC12903CF799E.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/I/TRAAILW128F146704C.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/I/TRAAIMC128F42625C6.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/I/TRAAIMO128F92EB778.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/I/TRAAINT128F933BBE0.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/I/TRAAIQG128F425204F.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/I/TRAAIQS128F9301078.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/I/TRAAISG128F92DCED6.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/I/TRAAIUW128F4290B94.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/I/TRAAIXG128F4297071.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/J/TRAAJAC12903CEB847.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/J/TRAAJAX128F4236AD6.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/J/TRAAJBP12903CC459C.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/J/TRAAJEK128F422F55A.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/J/TRAAJET128F932E790.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/J/TRAAJHI128F4275B83.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/J/TRAAJJG128F4284B27.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/J/TRAAJJI128F933E890.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/J/TRAAJJV128F42A2F99.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/J/TRAAJJW128F4298683.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/J/TRAAJJW12903CBDDCB.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/J/TRAAJKJ128F92FB44F.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/J/TRAAJOA128F145FB71.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/J/TRAAJPG128F42292ED.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/J/TRAAJPJ128F9333092.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/J/TRAAJRN128F92EFDDB.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/J/TRAAJSV128F92F8EB8.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/J/TRAAJSX128F4275A1D.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/J/TRAAJUT12903CF126E.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/J/TRAAJWM128F9346ADB.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/J/TRAAJXQ128F92E65BF.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/J/TRAAJXX128F4239802.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/J/TRAAJYX128F4255568.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/K/TRAAKAS128F4246013.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/K/TRAAKAV128F931BE25.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/K/TRAAKBQ12903CACE08.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/K/TRAAKDF128F92FA302.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/K/TRAAKDG128F42A0ECB.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/K/TRAAKDJ12903D09573.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/K/TRAAKDN128F930A7B8.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/K/TRAAKFF128F42B69BD.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/K/TRAAKJE128F930987C.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/K/TRAAKLG128F930E6DF.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/K/TRAAKLG128F93453BB.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/K/TRAAKLQ12903CB0D25.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/K/TRAAKMD128F1497E6C.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/K/TRAAKMS12903CDCF78.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/K/TRAAKMX128F934B494.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/K/TRAAKNS12903CC5198.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/K/TRAAKOJ128F932BF6B.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/K/TRAAKOV12903CA721B.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/K/TRAAKRN128F92FF8D0.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/K/TRAAKSH128F422E88C.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/K/TRAAKSR128F93593F0.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/K/TRAAKUB128F421A5CE.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/K/TRAAKUC128F934FDDE.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/K/TRAAKUZ128F423F40A.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/K/TRAAKVQ128F425C39D.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/K/TRAAKVZ12903D074BB.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/L/TRAALAH128E078234A.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/L/TRAALBU128F92EC05A.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/L/TRAALCM128F4264370.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/L/TRAALDI128EF35F6DD.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/L/TRAALDU128F930D56B.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/L/TRAALGY12903CBA247.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/L/TRAALMJ128E0785DF5.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/L/TRAALNG12903D014E9.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/L/TRAALNZ128F934B373.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/L/TRAALOF128F427FE6B.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/L/TRAALPA128F1451DB0.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/L/TRAALPK128F427641F.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/L/TRAALPN128F9336DC1.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/L/TRAALQA12903D0DC75.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/L/TRAALRL128F92EDA8A.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/L/TRAALRO12903CB375C.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/L/TRAALTN128F93087C0.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/L/TRAALUX12903CFD50B.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/L/TRAALUZ128F932B42B.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/L/TRAALVQ128F932C7E0.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/L/TRAALVQ128F933B48C.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/L/TRAALWY128F423EE73.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/L/TRAALYN128F1452482.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/M/TRAAMAI128F426A0AD.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/M/TRAAMBM128F933DBBF.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/M/TRAAMCQ128F4259A2F.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/M/TRAAMDH12903CCF659.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/M/TRAAMDZ128F146340C.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/M/TRAAMES128F42AF068.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/M/TRAAMFT128F93128AD.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/M/TRAAMHN128F42956E6.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/M/TRAAMIO128EF3626C3.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/M/TRAAMLN128F92F9634.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/M/TRAAMLX12903CF5B92.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/M/TRAAMPA128F92E7D0D.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/M/TRAAMPD128F145CE7C.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/M/TRAAMQV128F4280C07.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/M/TRAAMRI128F932C16D.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/M/TRAAMRO128F92F20D7.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/M/TRAAMSH128F14735B3.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/M/TRAAMSZ128F423DCB0.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/M/TRAAMTG128F933686E.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/M/TRAAMUZ128F9327055.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/M/TRAAMXN128F148AD52.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/M/TRAAMZV128F149A302.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/N/TRAANBH128F9345A6C.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/N/TRAANEA12903CF1452.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/N/TRAANFL12903CC4730.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/N/TRAANFR12903CC5133.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/N/TRAANIX128F92DF5E3.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/N/TRAANJF12903CF11A0.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/N/TRAANJI128F426B696.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/N/TRAANJM128F9339920.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/N/TRAANJZ128E078264F.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/N/TRAANLT128F934BB3F.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/N/TRAANND128F930CCC1.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/N/TRAANOM128F425E4AF.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/N/TRAANOY128F93328C6.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/N/TRAANRJ128F931D72D.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/N/TRAANRS128F92E4F27.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/N/TRAANSB128F9320884.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/N/TRAANSU128F424943B.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/N/TRAANSZ128F425DD63.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/N/TRAANTY12903CAE21E.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/N/TRAANVK128F93065D5.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/N/TRAANZR128F147B436.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/O/TRAAOAG128E078A3C0.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/O/TRAAOAL128F9306650.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/O/TRAAODR128F146155C.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/O/TRAAODT12903D0D16E.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/O/TRAAOFS128F9309414.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/O/TRAAOGH128F92CA518.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/O/TRAAOGR128F425E7BF.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/O/TRAAOIC128F9338C21.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/O/TRAAOIH128F92F0679.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/O/TRAAOIN128F9303790.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/O/TRAAOJM12903CBD45A.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/O/TRAAONF128F92FDEE9.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/O/TRAAOPV128F92F7CE9.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/O/TRAAOQW128F92FEB9B.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/O/TRAAORB128F930A97F.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/O/TRAAORZ128F421CB5C.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/O/TRAAOTT128F14AE002.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/O/TRAAOUU128F4262FAE.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/O/TRAAOXM12903CFB3B0.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/O/TRAAOYP128F425EEB5.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/P/TRAAPAP128F149ECA1.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/P/TRAAPAU128F92DB7ED.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/P/TRAAPCL128F930CB6C.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/P/TRAAPFE12903CF5DF4.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/P/TRAAPFN128F422AEDF.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/P/TRAAPGF128F1458F8B.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/P/TRAAPHH128F145D947.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/P/TRAAPHJ128F4290FB2.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/P/TRAAPHO128F92DE6D6.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/P/TRAAPKN128F429CE4D.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/P/TRAAPKW128F428BC93.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/P/TRAAPMJ128F426AC0A.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/P/TRAAPMU128F14B0B3D.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/P/TRAAPNM128F4280813.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/P/TRAAPOT128F427C20E.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/P/TRAAPOW12903CAE698.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/P/TRAAPPH128F428B0B7.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/P/TRAAPPQ128F14961F5.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/P/TRAAPPQ12903D0129F.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/P/TRAAPSN128F422B2F7.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/P/TRAAPSR128F932BDAD.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/P/TRAAPVB12903CDD85D.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/P/TRAAPVV128F92FD037.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/P/TRAAPWD128F931ACD4.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/P/TRAAPWE128F932DE02.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/P/TRAAPZB128F4295C29.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/Q/TRAAQAL128F92EA7A7.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/Q/TRAAQBF12903CF796B.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/Q/TRAAQCI128F4257A4F.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/Q/TRAAQCK128F92E8C33.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/Q/TRAAQGL128F9308363.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/Q/TRAAQIH128F428BDEA.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/Q/TRAAQLJ128F428E870.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/Q/TRAAQOU128F92D5955.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/Q/TRAAQPI128F1489569.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/Q/TRAAQPP12903CE6658.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/Q/TRAAQTM128F426B6E6.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/Q/TRAAQUC128F9322A82.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/Q/TRAAQUU128F42901ED.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/Q/TRAAQVX128F14958EB.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/Q/TRAAQXO128F933E779.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/Q/TRAAQYH128F92D5C30.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/Q/TRAAQYQ12903CF1193.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/R/TRAARAC128F933532B.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/R/TRAARBJ128F9328B09.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/R/TRAARCZ128F42B3EFE.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/R/TRAAREW12903CAEF29.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/R/TRAARFP128F42A8241.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/R/TRAARGK12903CFC484.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/R/TRAARIH128F146542C.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/R/TRAARKG128F42AC406.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/R/TRAARLK12903CD3764.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/R/TRAARLU128F421DA64.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/R/TRAARMC128F92F4F42.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/R/TRAARMW128F424A387.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/R/TRAAROA128F931663B.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/R/TRAARPG128F424FECB.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/R/TRAARQN128E07894DF.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/R/TRAARRJ128F92CEA23.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/R/TRAARSU12903CB63F0.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/R/TRAARUB128F4290C74.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/R/TRAARWB128F14A9496.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/R/TRAARXB128F92FA0BF.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/R/TRAARXD12903D0CF24.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/R/TRAARYB128F93124A1.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/R/TRAARYN128F92D687A.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/R/TRAARZD128F92D4A44.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/R/TRAARZE128F93264E9.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/R/TRAARZK12903D14A2D.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/S/TRAASAU12903CF6274.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/S/TRAASBR128F92F2CEF.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/S/TRAASCL12903CBF14F.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/S/TRAASDM128F92DC1FE.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/S/TRAASDN128F9343C1C.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/S/TRAASED12903CEE1C5.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/S/TRAASFP128F42980BD.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/S/TRAASGM128EF34DBB0.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/S/TRAASHC128F427ED9F.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/S/TRAASKO128F427CE1C.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/S/TRAASLO128F92DFAC5.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/S/TRAASMT12903CC238B.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/S/TRAASOA128F930A8DB.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/S/TRAASOK128F4250DC4.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/S/TRAASOR128F42605F7.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/S/TRAASPL128F4286EE9.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/S/TRAASPT128F423AB04.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/S/TRAASQC128F93480F0.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/S/TRAASQP128F1474C85.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/S/TRAASSO12903CDD2FF.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/S/TRAASZP128F92C96B3.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/S/TRAASZT128F423350F.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/T/TRAATBN128F14ACE82.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/T/TRAATCK128F92D7592.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/T/TRAATCO128F429D8DE.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/T/TRAATFW128F14957A8.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/T/TRAATGG12903CA1A41.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/T/TRAATGM12903C9CD7C.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/T/TRAATIR128F92FC91C.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/T/TRAATIU128F4291A84.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/T/TRAATJK128F9339179.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/T/TRAATKC128F92FCC95.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/T/TRAATKF128E0786B4B.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/T/TRAATLC12903D0172B.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/T/TRAATLN128F425399A.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/T/TRAATMF128F147921E.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/T/TRAATMI128F9366CA1.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/T/TRAATPA128F146753C.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/T/TRAATSK128E078787D.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/T/TRAATSW128F4263B0E.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/T/TRAATWN12903CAFC3A.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/T/TRAATWQ12903CC5BA8.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/T/TRAATXI128F428228E.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/T/TRAATYZ128F4256545.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/T/TRAATZX128F92D1DD3.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/T/TRAATZY128F428249B.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/U/TRAAUAQ128F9340451.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/U/TRAAUED128F423ED67.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/U/TRAAUEO128E0780CB9.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/U/TRAAUFM128F92F38FA.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/U/TRAAUFV128EF35F02C.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/U/TRAAUGD128F42734DA.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/U/TRAAUGW12903CCE184.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/U/TRAAUIH128F4254C9D.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/U/TRAAUKD128F14613E4.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/U/TRAAUKK128F933A680.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/U/TRAAUKQ128F429B7A5.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/U/TRAAULB128F4270576.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/U/TRAAUMZ128E0796151.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/U/TRAAUQF12903CC4A4D.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/U/TRAAUSW128F426646E.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/U/TRAAUTR12903CAFCA9.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/U/TRAAUUZ128F932A46E.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/U/TRAAUVC128F428A0AE.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/U/TRAAUWD128F930DD4E.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/U/TRAAUZB128F92EC067.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/U/TRAAUZI12903CAFD53.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/U/TRAAUZX128F92F3D53.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/V/TRAAVBL128F426B7CD.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/V/TRAAVBM128F9315516.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/V/TRAAVDQ12903CF5D97.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/V/TRAAVDV128F931F2A3.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/V/TRAAVFL128F425D247.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/V/TRAAVHN128F931DD37.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/V/TRAAVJL128F14ACADD.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/V/TRAAVMO128F426BC1D.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/V/TRAAVOI128F1482FCE.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/V/TRAAVOJ128F92FC0C8.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/V/TRAAVOK12903CC4773.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/V/TRAAVOU128F422F292.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/V/TRAAVPC12903CF7C01.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/V/TRAAVQV128F148DFEF.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/V/TRAAVRJ128F92FF90A.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/V/TRAAVRU128F423EAE2.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/V/TRAAVWA128F145D887.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/V/TRAAVYC12903CE35CD.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/V/TRAAVZB12903CC6C5A.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/W/TRAAWAA12903CE1C8C.json')
# ...
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/J/TRARJPU128F9326A86.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/J/TRARJRQ128F931C80D.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/J/TRARJSH128F146EF62.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/J/TRARJVW128F14937AB.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/J/TRARJWJ12903CD9952.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/J/TRARJZN128F92E5043.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/K/TRARKBB128F92E9468.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/K/TRARKBI128F145DDAD.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/K/TRARKBI12903CE42E6.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/K/TRARKDH128F4270965.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/K/TRARKDL12903CCC360.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/K/TRARKDW128F42BCD33.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/K/TRARKEA128F1468EB8.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/K/TRARKEF128F42634F6.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/K/TRARKEH128F1463CB2.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/K/TRARKGW128F92EB8F9.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/K/TRARKID128F423DADF.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/K/TRARKLX128F934C646.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/K/TRARKMP128F42704C8.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/K/TRARKMZ128F42AD0A3.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/K/TRARKPD128F92E0535.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/K/TRARKPS128E078478C.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/K/TRARKPU128F933ABC6.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/K/TRARKQW128E07872D8.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/K/TRARKRC128E0791D82.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/K/TRARKRC12903CC2722.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/K/TRARKSF128EF35F6D0.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/K/TRARKSK12903CF5DAB.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/K/TRARKVN128F92C9E51.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/K/TRARKXM128F14911B0.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/K/TRARKYB12903CB9AD1.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/K/TRARKZJ128F934B2F2.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/L/TRARLCN128F92D7218.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/L/TRARLDD128F425E216.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/L/TRARLDZ128F1464ED9.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/L/TRARLGD128F93119C1.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/L/TRARLGJ128F933C003.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/L/TRARLGS128EF34D3E6.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/L/TRARLHI128F42813D9.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/L/TRARLHT12903CE2E16.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/L/TRARLIU128F934C2E5.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/L/TRARLLN128F42596B8.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/L/TRARLLW128F93011B5.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/L/TRARLMK12903CDF354.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/L/TRARLNS12903CBD52F.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/L/TRARLPT128F4277A25.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/L/TRARLQL128F933D3F3.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/L/TRARLYO12903CB4901.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/L/TRARLZF128F14840C6.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/L/TRARLZW128F429E9AB.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/M/TRARMBF128F42A3F59.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/R/M/TRARMDD128F428A189.json')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 11
#       3 s3 = boto3.resource('s3',
#       4                        region_name="us-west-2",
#       5                        aws_access_key_id=KEY,
#       6                        aws_secret_access_key=SECRET
#       7                      )
#       9 sampleDbBucket =  s3.Bucket("udacity-dend")
# ---> 11 for obj in sampleDbBucket.objects.filter(Prefix="song_data"):
#      12     print(obj)
#
# File ~/Documents/Code/UdacityCloudDeveloper/envs/lib/python3.12/site-packages/boto3/resources/collection.py:81, in ResourceCollection.__iter__(self)
#      78 limit = self._params.get('limit', None)
#      80 count = 0
# ---> 81 for page in self.pages():
#      82     for item in page:
#      83         yield item
#
# File ~/Documents/Code/UdacityCloudDeveloper/envs/lib/python3.12/site-packages/boto3/resources/collection.py:171, in ResourceCollection.pages(self)
#     168 # Now that we have a page iterator or single page of results
#     169 # we start processing and yielding individual items.
#     170 count = 0
# --> 171 for page in pages:
#     172     page_items = []
#     173     for item in self._handler(self._parent, params, page):
#
# File ~/Documents/Code/UdacityCloudDeveloper/envs/lib/python3.12/site-packages/botocore/paginate.py:269, in PageIterator.__iter__(self)
#     267 self._inject_starting_params(current_kwargs)
#     268 while True:
# --> 269     response = self._make_request(current_kwargs)
#     270     parsed = self._extract_parsed_response(response)
#     271     if first_request:
#     272         # The first request is handled differently.  We could
#     273         # possibly have a resume/starting token that tells us where
#     274         # to index into the retrieved page.
#
# File ~/Documents/Code/UdacityCloudDeveloper/envs/lib/python3.12/site-packages/botocore/paginate.py:357, in PageIterator._make_request(self, current_kwargs)
#     356 def _make_request(self, current_kwargs):
# --> 357     return self._method(**current_kwargs)
#
# File ~/Documents/Code/UdacityCloudDeveloper/envs/lib/python3.12/site-packages/botocore/client.py:565, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     561     raise TypeError(
#     562         f"{py_operation_name}() only accepts keyword arguments."
#     563     )
#     564 # The "self" in this scope is referring to the BaseClient.
# --> 565 return self._make_api_call(operation_name, kwargs)
#
# File ~/Documents/Code/UdacityCloudDeveloper/envs/lib/python3.12/site-packages/botocore/client.py:1001, in BaseClient._make_api_call(self, operation_name, api_params)
#     997     maybe_compress_request(
#     998         self.meta.config, request_dict, operation_model
#     999     )
#    1000     apply_request_checksum(request_dict)
# -> 1001     http, parsed_response = self._make_request(
#    1002         operation_model, request_dict, request_context
#    1003     )
#    1005 self.meta.events.emit(
#    1006     'after-call.{service_id}.{operation_name}'.format(
#    1007         service_id=service_id, operation_name=operation_name
#    (...)
#    1012     context=request_context,
#    1013 )
#    1015 if http.status_code >= 300:
#
# File ~/Documents/Code/UdacityCloudDeveloper/envs/lib/python3.12/site-packages/botocore/client.py:1027, in BaseClient._make_request(self, operation_model, request_dict, request_context)
#    1025 def _make_request(self, operation_model, request_dict, request_context):
#    1026     try:
# -> 1027         return self._endpoint.make_request(operation_model, request_dict)
#    1028     except Exception as e:
#    1029         self.meta.events.emit(
#    1030             'after-call-error.{service_id}.{operation_name}'.format(
#    1031                 service_id=self._service_model.service_id.hyphenize(),
#    (...)
#    1035             context=request_context,
#    1036         )
#
# File ~/Documents/Code/UdacityCloudDeveloper/envs/lib/python3.12/site-packages/botocore/endpoint.py:119, in Endpoint.make_request(self, operation_model, request_dict)
#     113 def make_request(self, operation_model, request_dict):
#     114     logger.debug(
#     115         "Making request for %s with params: %s",
#     116         operation_model,
#     117         request_dict,
#     118     )
# --> 119     return self._send_request(request_dict, operation_model)
#
# File ~/Documents/Code/UdacityCloudDeveloper/envs/lib/python3.12/site-packages/botocore/endpoint.py:199, in Endpoint._send_request(self, request_dict, operation_model)
#     197 self._update_retries_context(context, attempts)
#     198 request = self.create_request(request_dict, operation_model)
# --> 199 success_response, exception = self._get_response(
#     200     request, operation_model, context
#     201 )
#     202 while self._needs_retry(
#     203     attempts,
#     204     operation_model,
#    (...)
#     207     exception,
#     208 ):
#     209     attempts += 1
#
# File ~/Documents/Code/UdacityCloudDeveloper/envs/lib/python3.12/site-packages/botocore/endpoint.py:241, in Endpoint._get_response(self, request, operation_model, context)
#     235 def _get_response(self, request, operation_model, context):
#     236     # This will return a tuple of (success_response, exception)
#     237     # and success_response is itself a tuple of
#     238     # (http_response, parsed_dict).
#     239     # If an exception occurs then the success_response is None.
#     240     # If no exception occurs then exception is None.
# --> 241     success_response, exception = self._do_get_response(
#     242         request, operation_model, context
#     243     )
#     244     kwargs_to_emit = {
#     245         'response_dict': None,
#     246         'parsed_response': None,
#     247         'context': context,
#     248         'exception': exception,
#     249     }
#     250     if success_response is not None:
#
# File ~/Documents/Code/UdacityCloudDeveloper/envs/lib/python3.12/site-packages/botocore/endpoint.py:281, in Endpoint._do_get_response(self, request, operation_model, context)
#     279     http_response = first_non_none_response(responses)
#     280     if http_response is None:
# --> 281         http_response = self._send(request)
#     282 except HTTPClientError as e:
#     283     return (None, e)
#
# File ~/Documents/Code/UdacityCloudDeveloper/envs/lib/python3.12/site-packages/botocore/endpoint.py:377, in Endpoint._send(self, request)
#     376 def _send(self, request):
# --> 377     return self.http_session.send(request)
#
# File ~/Documents/Code/UdacityCloudDeveloper/envs/lib/python3.12/site-packages/botocore/httpsession.py:464, in URLLib3Session.send(self, request)
#     461     conn.proxy_headers['host'] = host
#     463 request_target = self._get_request_target(request.url, proxy_url)
# --> 464 urllib_response = conn.urlopen(
#     465     method=request.method,
#     466     url=request_target,
#     467     body=request.body,
#     468     headers=request.headers,
#     469     retries=Retry(False),
#     470     assert_same_host=False,
#     471     preload_content=False,
#     472     decode_content=False,
#     473     chunked=self._chunked(request.headers),
#     474 )
#     476 http_response = botocore.awsrequest.AWSResponse(
#     477     request.url,
#     478     urllib_response.status,
#     479     urllib_response.headers,
#     480     urllib_response,
#     481 )
#     483 if not request.stream_output:
#     484     # Cause the raw stream to be exhausted immediately. We do it
#     485     # this way instead of using preload_content because
#     486     # preload_content will never buffer chunked responses
#
# File ~/Documents/Code/UdacityCloudDeveloper/envs/lib/python3.12/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File ~/Documents/Code/UdacityCloudDeveloper/envs/lib/python3.12/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Documents/Code/UdacityCloudDeveloper/envs/lib/python3.12/site-packages/urllib3/connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File ~/Documents/Code/UdacityCloudDeveloper/envs/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File ~/Documents/Code/UdacityCloudDeveloper/envs/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~/Documents/Code/UdacityCloudDeveloper/envs/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~/Documents/Code/UdacityCloudDeveloper/envs/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File ~/Documents/Code/UdacityCloudDeveloper/envs/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File ~/Documents/Code/UdacityCloudDeveloper/envs/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # Data Exploration

# %%
import pandasql as ps
import pandas as pd
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
cur.execute("""
select * from song_events
""")
rows = cur.fetchall()
column_names = [desc[0] for desc in cur.description]
song_events = pd.DataFrame(rows, columns=column_names)

# %%
song_events.head()
# Out:
#           artist        auth firstname gender  iteminsession  lastname  \
# 0           None  Logged Out      None   None              0      None
# 1           None   Logged In   Celeste      F              1  Williams
# 2           Mynt   Logged In   Celeste      F              2  Williams
# 3   Taylor Swift   Logged In   Celeste      F              3  Williams
# 4  Amy Winehouse   Logged In   Celeste      F              4  Williams
#
#       length level           location method      page  registration  \
# 0        NaN  free               None    PUT     Login           NaN
# 1        NaN  free  Klamath Falls, OR    GET      Home  1.541078e+12
# 2  166.94812  free  Klamath Falls, OR    PUT  NextSong  1.541078e+12
# 3  230.47791  free  Klamath Falls, OR    PUT  NextSong  1.541078e+12
# 4  229.85098  free  Klamath Falls, OR    PUT  NextSong  1.541078e+12
#
#    sessionid                song  status             ts  \
# 0         52                None     307  1541207073796
# 1         52                None     200  1541207123796
# 2         52        Playa Haters     200  1541207150796
# 3         52  You Belong With Me     200  1541207316796
# 4         52             Valerie     200  1541207546796
#
#                                                                                                          useragent  \
# 0                                                                                                             None
# 1  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.103 Safari/537.36"
# 2  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.103 Safari/537.36"
# 3  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.103 Safari/537.36"
# 4  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.103 Safari/537.36"
#
#    userid
# 0     NaN
# 1    53.0
# 2    53.0
# 3    53.0
# 4    53.0

# %%
cur.execute("""
select page, count(1) from song_events group by 1
""")
rows = cur.fetchall()
column_names = [desc[0] for desc in cur.description]
pd.DataFrame(rows, columns=column_names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 cur.execute("""
#       2 select page, count(1) from song_events group by 1
#       3 """)
#       4 rows = cur.fetchall()
#       5 column_names = [desc[0] for desc in cur.description]
#
# NameError: name 'cur' is not defined

# %%
cur.execute("""
select auth, count(1) from song_events where page = 'NextSong' group by 1
""")
rows = cur.fetchall()
column_names = [desc[0] for desc in cur.description]
pd.DataFrame(rows, columns=column_names)
# Out:
#         auth  count
# 0  Logged In   6820

# %%
cur.execute(
    """
select distinct
    artist_id, 
    artist_latitude,
    artist_longitude,
    artist_location,
    artist_name
from songs
limit 100
"""
)
rows = cur.fetchall()
column_names = [desc[0] for desc in cur.description]
pd.DataFrame(rows, columns=column_names)
# Out:
#              artist_id artist_latitude artist_longitude  artist_location  \
# 0   AREW1KO1187B98E42E            None             None
# 1   AR7AE0W1187B98E40E            None             None
# 2   ART09111187FB5BF48       32.365029       -88.703069     Meridian, MS
# 3   ARHGQUW1187FB3905C            None             None
# 4   ARPOUCK11E8DC5262E            None             None
# ..                 ...             ...              ...              ...
# 95  ARX5KUX1187B989C8D            None             None
# 96  ARMYMUD1187B9B018E       51.506320        -0.127140  London, England
# 97  ARKA3ZA11C8A422F8F            None             None
# 98  AR37ILI1187B98E27B            None             None  London, England
# 99  ARVAPVX1187FB48225       64.950140        26.067390          Finland
#
#                      artist_name
# 0               The Irish Tenors
# 1                      Intocable
# 2   Ty Herndon;Stephanie Bentley
# 3                King of Prussia
# 4                The Melismatics
# ..                           ...
# 95                Expensive Soul
# 96            The Wolfgang Press
# 97                    Futurecop!
# 98                    Shriekback
# 99                    Lackluster
#
# [100 rows x 5 columns]

# %%
songs.head()
# Out:
#    num_songs           artist_id artist_latitude artist_longitude  \
# 0          1  ARWCIEL1187FB42EF5       39.290550       -76.609600
# 1          1  ARHAJH611C8A4219F1            None             None
# 2          1  AR6Y22S1187B99906F            None             None
# 3          1  AROVXZM1187FB3C3DB            None             None
# 4          1  ARVYYRY1187B9953F0      -26.204940        28.040030
#
#               artist_location           artist_name             song_id  \
# 0                      B-More           Beach House  SOGMORP12A8C13EF63
# 1                              La Bottega Dell'Arte  SODJYTL12A8C14550E
# 2                                         Smartbomb  SONSPZE12AB01819CE
# 3                                    Richard Durand  SOIQFYZ12AB017D108
# 4  Johannesburg, South Africa          Trevor Rabin  SOJDUQC12AB0181FE6
#
#                         title   duration  year
# 0            Auburn and Ivory  270.00117  2006
# 1  Noi Nel Bene_ Noi Nel Male  223.24199     0
# 2               Complicate It  233.27302  2001
# 3          Weep (Sundown Mix)  510.01423     0
# 4             Siphon Searches  242.96444  2009

# %%
songs.groupby('num_songs')['artist_id'].count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 songs.groupby('num_songs')['artist_id'].count()
#
# NameError: name 'songs' is not defined

# %%
cur.execute("""
SELECT count(1)
FROM stg_song_events 
""")
rows = cur.fetchall()
column_names = [desc[0] for desc in cur.description]
pd.DataFrame(rows, columns=column_names)
# Out:
#    count
# 0   8056

# %%
cur.execute("""
SELECT count(1)
FROM stg_songs 
""")
rows = cur.fetchall()
column_names = [desc[0] for desc in cur.description]
pd.DataFrame(rows, columns=column_names)
# Out:
#    count
# 0  14896

# %%
cur.execute("""
SELECT count(1)
FROM song_plays 
""")
rows = cur.fetchall()
column_names = [desc[0] for desc in cur.description]
pd.DataFrame(rows, columns=column_names)
# Out:
#    count
# 0   6820

# %%
cur.execute("""
SELECT count(1)
FROM users 
""")
rows = cur.fetchall()
column_names = [desc[0] for desc in cur.description]
pd.DataFrame(rows, columns=column_names)
# Out:
#    count
# 0    107

# %%
cur.execute("""
SELECT count(1)
FROM songs 
""")
rows = cur.fetchall()
column_names = [desc[0] for desc in cur.description]
pd.DataFrame(rows, columns=column_names)
# Out:
#    count
# 0  14896

# %%
cur.execute("""
SELECT count(1)
FROM artists 
""")
rows = cur.fetchall()
column_names = [desc[0] for desc in cur.description]
pd.DataFrame(rows, columns=column_names)
# Out:
#    count
# 0  10025

# %%
cur.execute("""
SELECT count(1)
FROM time_dimensions 
""")
rows = cur.fetchall()
column_names = [desc[0] for desc in cur.description]
pd.DataFrame(rows, columns=column_names)
# Out:
#    count
# 0   8023

# %%
cur.execute("""
SELECT TIMESTAMP 'epoch' + ts/1000 * INTERVAL '1 second', *
FROM stg_song_events
LIMIT 20
""")
rows = cur.fetchall()
column_names = [desc[0] for desc in cur.description]
pd.DataFrame(rows, columns=column_names)
# Out:
#               ?column?                         artist       auth firstname  \
# 0  2018-11-05 00:33:12                  A Fine Frenzy  Logged In  Anabelle
# 1  2018-11-05 01:27:22                        Nirvana  Logged In    Aleena
# 2  2018-11-05 01:30:56                     Television  Logged In    Aleena
# 3  2018-11-05 01:34:54                  JOHN COLTRANE  Logged In    Aleena
# 4  2018-11-05 01:40:40                           NOFX  Logged In    Aleena
# 5  2018-11-05 01:42:00              The Backyardigans  Logged In    Aleena
# 6  2018-11-05 01:44:38              Bruce Springsteen  Logged In    Aleena
# 7  2018-11-05 01:48:00                       Maroon 5  Logged In    Aleena
# 8  2018-11-05 01:50:53           Two Door Cinema Club  Logged In    Aleena
# 9  2018-11-05 01:54:02        Five Finger Death Punch  Logged In    Aleena
# 10 2018-11-05 01:58:24                    Josh Turner  Logged In    Aleena
# 11 2018-11-05 02:01:51                At The Drive-In  Logged In    Aleena
# 12 2018-11-05 02:05:18              Animal Collective  Logged In    Aleena
# 13 2018-11-05 02:09:47                     Ron Carter  Logged In    Aleena
# 14 2018-11-05 02:18:04                       Old 97's  Logged In    Aleena
# 15 2018-11-05 02:21:55                   Cyndi Lauper  Logged In    Aleena
# 16 2018-11-05 02:25:41                    Damien Rice  Logged In    Aleena
# 17 2018-11-05 02:30:17                    Alicia Keys  Logged In    Aleena
# 18 2018-11-05 02:34:06  Lloyd Cole And The Commotions  Logged In    Aleena
# 19 2018-11-05 02:38:01                     John Mayer  Logged In    Aleena
#
#    gender  iteminsession lastname     length level  \
# 0       F              0  Simpson  267.91138  free
# 1       F              0    Kirby  214.77832  paid
# 2       F              1    Kirby  238.49751  paid
# 3       F              2    Kirby  346.43546  paid
# 4       F              3    Kirby   80.79628  paid
# 5       F              4    Kirby  158.85016  paid
# 6       F              5    Kirby  202.84036  paid
# 7       F              6    Kirby  173.66159  paid
# 8       F              7    Kirby  189.67465  paid
# 9       F              8    Kirby  262.81751  paid
# 10      F              9    Kirby  207.93424  paid
# 11      F             10    Kirby  207.46404  paid
# 12      F             11    Kirby  269.81832  paid
# 13      F             12    Kirby  497.13587  paid
# 14      F             13    Kirby  231.28771  paid
# 15      F             14    Kirby  226.32444  paid
# 16      F             15    Kirby  276.08771  paid
# 17      F             16    Kirby  229.06730  paid
# 18      F             17    Kirby  235.31057  paid
# 19      F             18    Kirby  269.71383  paid
#
#                                        location method      page  \
# 0   Philadelphia-Camden-Wilmington, PA-NJ-DE-MD    PUT  NextSong
# 1                      Waterloo-Cedar Falls, IA    PUT  NextSong
# 2                      Waterloo-Cedar Falls, IA    PUT  NextSong
# 3                      Waterloo-Cedar Falls, IA    PUT  NextSong
# 4                      Waterloo-Cedar Falls, IA    PUT  NextSong
# 5                      Waterloo-Cedar Falls, IA    PUT  NextSong
# 6                      Waterloo-Cedar Falls, IA    PUT  NextSong
# 7                      Waterloo-Cedar Falls, IA    PUT  NextSong
# 8                      Waterloo-Cedar Falls, IA    PUT  NextSong
# 9                      Waterloo-Cedar Falls, IA    PUT  NextSong
# 10                     Waterloo-Cedar Falls, IA    PUT  NextSong
# 11                     Waterloo-Cedar Falls, IA    PUT  NextSong
# 12                     Waterloo-Cedar Falls, IA    PUT  NextSong
# 13                     Waterloo-Cedar Falls, IA    PUT  NextSong
# 14                     Waterloo-Cedar Falls, IA    PUT  NextSong
# 15                     Waterloo-Cedar Falls, IA    PUT  NextSong
# 16                     Waterloo-Cedar Falls, IA    PUT  NextSong
# 17                     Waterloo-Cedar Falls, IA    PUT  NextSong
# 18                     Waterloo-Cedar Falls, IA    PUT  NextSong
# 19                     Waterloo-Cedar Falls, IA    PUT  NextSong
#
#      registration  sessionid                                  song  status  \
# 0   1541044398796        256          Almost Lover (Album Version)     200
# 1   1541022995796        237                    Serve The Servants     200
# 2   1541022995796        237  See No Evil  (Remastered LP Version)     200
# 3   1541022995796        237          Blues To Bechet (LP Version)     200
# 4   1541022995796        237   It's My Job To Keep Punk Rock Elite     200
# 5   1541022995796        237                 Into The Thick Of It!     200
# 6   1541022995796        237                         Radio Nowhere     200
# 7   1541022995796        237                     Harder To Breathe     200
# 8   1541022995796        237                         What You Know     200
# 9   1541022995796        237                      Meet the Monster     200
# 10  1541022995796        237                         What It Ain't     200
# 11  1541022995796        237                    Sleepwalk Capsules     200
# 12  1541022995796        237                    Summertime Clothes     200
# 13  1541022995796        237                   I CAN'T GET STARTED     200
# 14  1541022995796        237                 Victoria (LP Version)     200
# 15  1541022995796        237                           True Colors     200
# 16  1541022995796        237                                  Amie     200
# 17  1541022995796        237                    If I Ain't Got You     200
# 18  1541022995796        237                      Charlotte Street     200
# 19  1541022995796        237                    Heartbreak Warfare     200
#
#                ts  \
# 0   1541377992796
# 1   1541381242796
# 2   1541381456796
# 3   1541381694796
# 4   1541382040796
# 5   1541382120796
# 6   1541382278796
# 7   1541382480796
# 8   1541382653796
# 9   1541382842796
# 10  1541383104796
# 11  1541383311796
# 12  1541383518796
# 13  1541383787796
# 14  1541384284796
# 15  1541384515796
# 16  1541384741796
# 17  1541385017796
# 18  1541385246796
# 19  1541385481796
#
#                                                                                                                      useragent  \
# 0   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"
# 1                                            Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0
# 2                                            Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0
# 3                                            Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0
# 4                                            Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0
# 5                                            Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0
# 6                                            Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0
# 7                                            Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0
# 8                                            Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0
# 9                                            Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0
# 10                                           Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0
# 11                                           Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0
# 12                                           Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0
# 13                                           Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0
# 14                                           Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0
# 15                                           Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0
# 16                                           Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0
# 17                                           Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0
# 18                                           Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0
# 19                                           Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0
#
#     userid
# 0       69
# 1       44
# 2       44
# 3       44
# 4       44
# 5       44
# 6       44
# 7       44
# 8       44
# 9       44
# 10      44
# 11      44
# 12      44
# 13      44
# 14      44
# 15      44
# 16      44
# 17      44
# 18      44
# 19      44

# %%
cur.execute("""
SELECT auth,
    iteminsession AS item_in_session,
    LEVEL,
    location,
    sessionid AS session_id,
    song,
    userid AS user_id,
    TIMESTAMP 'epoch' + ts/1000 * INTERVAL '1 second' AS time_key
FROM stg_song_events
WHERE PAGE = 'NextSong'
""")
rows = cur.fetchall()
column_names = [desc[0] for desc in cur.description]
pd.DataFrame(rows, columns=column_names)
# Out:
#            auth  item_in_session level  \
# 0     Logged In                0  free
# 1     Logged In                0  paid
# 2     Logged In                1  paid
# 3     Logged In                2  paid
# 4     Logged In                3  paid
# ...         ...              ...   ...
# 6815  Logged In               57  paid
# 6816  Logged In               58  paid
# 6817  Logged In               59  paid
# 6818  Logged In               60  paid
# 6819  Logged In                0  free
#
#                                          location  session_id  \
# 0     Philadelphia-Camden-Wilmington, PA-NJ-DE-MD         256
# 1                        Waterloo-Cedar Falls, IA         237
# 2                        Waterloo-Cedar Falls, IA         237
# 3                        Waterloo-Cedar Falls, IA         237
# 4                        Waterloo-Cedar Falls, IA         237
# ...                                           ...         ...
# 6815                        Birmingham-Hoover, AL        1076
# 6816                        Birmingham-Hoover, AL        1076
# 6817                        Birmingham-Hoover, AL        1076
# 6818                        Birmingham-Hoover, AL        1076
# 6819                  Detroit-Warren-Dearborn, MI         985
#
#                                        song  user_id            time_key
# 0              Almost Lover (Album Version)       69 2018-11-05 00:33:12
# 1                        Serve The Servants       44 2018-11-05 01:27:22
# 2      See No Evil  (Remastered LP Version)       44 2018-11-05 01:30:56
# 3              Blues To Bechet (LP Version)       44 2018-11-05 01:34:54
# 4       It's My Job To Keep Punk Rock Elite       44 2018-11-05 01:40:40
# ...                                     ...      ...                 ...
# 6815                          The Pretender       16 2018-11-30 18:40:05
# 6816                        Besos De Ceniza       16 2018-11-30 18:44:36
# 6817                                   Rose       16 2018-11-30 18:47:58
# 6818                           The Haunting       16 2018-11-30 18:51:24
# 6819  Anything You Say (Unreleased Version)        5 2018-11-30 19:54:24
#
# [6820 rows x 8 columns]

# %%
cur.execute(
    """
SELECT song,
    artist,
    COUNT(1)
FROM stg_song_events
WHERE PAGE = 'NextSong'
GROUP BY grouping sets ((song), (song, artist))
"""
)
rows = cur.fetchall()
column_names = [desc[0] for desc in cur.description]
pd.DataFrame(rows, columns=column_names)
# Out:
#                                        song          artist  count
# 0                                Supelicula   Maldita Nerea      1
# 1                                Din Din Wo  Habib KoitÃÂ©      1
# 2                               Greece 2000    Three Drives      5
# 3                                     Sorry  Jonas Brothers      1
# 4               Poor Leno Jakatta Radio Mix     RÃÂ¶yksopp      1
# ...                                     ...             ...    ...
# 10479                             Arboretum            None      1
# 10480                      Lay Down My Guns            None      1
# 10481                  The Woman Downstairs            None      1
# 10482  The Coolest (Explicit Album Version)            None      1
# 10483                            The Puzzle            None      1
#
# [10484 rows x 3 columns]

# %%
cur.execute(
    """
    SELECT DISTINCT 
    CAST(TO_CHAR(date_trunc('hour', TIMESTAMP 'epoch' + ts/1000 * INTERVAL '1 second'), 'YYYYMMDDHH24') AS bigint) AS time_key,
    TIMESTAMP 'epoch' + ts/1000 * INTERVAL '1 second' AS time_key
    FROM (select * from stg_song_events limit 100)
"""
)
rows = cur.fetchall()
column_names = [desc[0] for desc in cur.description]
pd.DataFrame(rows, columns=column_names)
# Out:
#       time_key            time_key
# 0   2018110301 2018-11-03 01:04:33
# 1   2018110301 2018-11-03 01:05:23
# 2   2018110301 2018-11-03 01:05:50
# 3   2018110301 2018-11-03 01:08:36
# 4   2018110301 2018-11-03 01:12:26
# ..         ...                 ...
# 95  2018110319 2018-11-03 19:13:33
# 96  2018110319 2018-11-03 19:17:17
# 97  2018110319 2018-11-03 19:21:49
# 98  2018110319 2018-11-03 19:26:20
# 99  2018110319 2018-11-03 19:27:48
#
# [100 rows x 2 columns]

# %%
cur.execute(
    """
WITH unique_times AS (
    SELECT DISTINCT 
        date_trunc('hour', TIMESTAMP 'epoch' + ts/1000 * INTERVAL '1 second') AS trunc_time
    FROM (select * from stg_song_events limit 100)
)
SELECT 
    CAST(TO_CHAR(trunc_time, 'YYYYMMDDHH24') AS bigint) AS time_key,
    CAST(SUBSTRING(CAST(trunc_time AS text) FROM 9 FOR 2) AS integer) AS hour,
    DATE(trunc_time) AS date,
    EXTRACT(
        DAY
        FROM trunc_time
    ) AS DAY,
    EXTRACT(
        WEEK
        FROM trunc_time
    ) AS week,
    EXTRACT(
        MONTH
        FROM trunc_time
    ) AS MONTH,
    EXTRACT(
        QUARTER
        FROM trunc_time
    ) AS quarter,
    EXTRACT(
        YEAR
        FROM trunc_time
    ) AS year,
    EXTRACT(
        DOW
        FROM trunc_time
    ) + 1 AS day_of_week,
    -- Redshift DOW: 0=Sunday, ..., 6=Saturday. Adding 1 to make it 1=Sunday, ..., 7=Saturday.
    CASE
        WHEN EXTRACT(
            DOW
            FROM trunc_time
        ) IN (0, 6) THEN TRUE
        ELSE FALSE
    END AS is_weekend,
    CASE
        WHEN EXTRACT(
            MONTH
            FROM trunc_time
        ) BETWEEN 1 AND 3 THEN EXTRACT(
            YEAR
            FROM trunc_time
        ) - 1
        ELSE EXTRACT(
            YEAR
            FROM trunc_time
        )
    END AS fiscal_year,
    CASE
        WHEN EXTRACT(
            MONTH
            FROM trunc_time
        ) BETWEEN 1 AND 3 THEN 4
        WHEN EXTRACT(
            MONTH
            FROM trunc_time
        ) BETWEEN 4 AND 6 THEN 1
        WHEN EXTRACT(
            MONTH
            FROM trunc_time
        ) BETWEEN 7 AND 9 THEN 2
        ELSE 3
    END AS fiscal_quarter,
    CASE
        WHEN EXTRACT(
            MONTH
            FROM trunc_time
        ) IN (12, 1, 2) THEN 'Winter'
        WHEN EXTRACT(
            MONTH
            FROM trunc_time
        ) IN (3, 4, 5) THEN 'Spring'
        WHEN EXTRACT(
            MONTH
            FROM trunc_time
        ) IN (6, 7, 8) THEN 'Summer'
        ELSE 'Fall'
    END AS season,
    NULL AS special_event -- Placeholder for any special events logic
FROM unique_times
"""
)
rows = cur.fetchall()
column_names = [desc[0] for desc in cur.description]
pd.DataFrame(rows, columns=column_names)
# Out:
# Empty DataFrame
# Columns: [time_key, hour, date, day, week, month, quarter, year, day_of_week, is_weekend, fiscal_year, fiscal_quarter, season, special_event]
# Index: []
